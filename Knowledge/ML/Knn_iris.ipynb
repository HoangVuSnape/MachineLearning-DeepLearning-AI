# %%
import numpy as np
import pandas as pd

# %%
filename = 'data\iris.data'
df = pd.read_csv(filename)
data = df.values
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\Snape\AppData\Local\Temp\ipykernel_16176\1284117926.py:1: SyntaxWarning: invalid escape sequence '\i'
#   filename = 'data\iris.data'

# %%
print(data.shape)
print(data[:2])
# Out:
# (149, 5)
# [[4.9 3.0 1.4 0.2 'Iris-setosa']
#  [4.7 3.2 1.3 0.2 'Iris-setosa']]

# %%
X = data[:, :-1]
y = data[:, -1]

# %%
name = df.columns.values.tolist()
f = df[name[4]].value_counts()
print(f)
f.plot.bar()
# Out:
# Iris-setosa
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# <Axes: xlabel='Iris-setosa'>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25, random_state= 42)

print(X_train.shape)
print(y_train.shape)

print(X_test.shape)
print(y_test.shape)
# Out:
# (111, 4)
# (111,)
# (38, 4)
# (38,)

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors= 3)
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

y_pred = model.predict(X_test) 
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[15  0  0]
#  [ 0  9  2]
#  [ 0  1 11]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        15
# Iris-versicolor       0.90      0.82      0.86        11
#  Iris-virginica       0.85      0.92      0.88        12
#
#        accuracy                           0.92        38
#       macro avg       0.92      0.91      0.91        38
#    weighted avg       0.92      0.92      0.92        38

# %%
y_pred
# Out:
# array(['Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa'], dtype=object)

# %%
compari = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
compari['result'] = compari['Actual'] == compari['Predicted']
print(compari)

result_com = compari['result'].value_counts()
print(result_com)
# Out:
#              Actual        Predicted  result
# 0   Iris-versicolor  Iris-versicolor    True
# 1       Iris-setosa      Iris-setosa    True
# 2    Iris-virginica   Iris-virginica    True
# 3   Iris-versicolor  Iris-versicolor    True
# 4   Iris-versicolor  Iris-versicolor    True
# 5       Iris-setosa      Iris-setosa    True
# 6   Iris-versicolor  Iris-versicolor    True
# 7    Iris-virginica   Iris-virginica    True
# 8   Iris-versicolor  Iris-versicolor    True
# 9   Iris-versicolor   Iris-virginica   False
# 10   Iris-virginica   Iris-virginica    True
# 11      Iris-setosa      Iris-setosa    True
# 12      Iris-setosa      Iris-setosa    True
# 13      Iris-setosa      Iris-setosa    True
# 14      Iris-setosa      Iris-setosa    True
# 15  Iris-versicolor  Iris-versicolor    True
# 16   Iris-virginica   Iris-virginica    True
# 17  Iris-versicolor   Iris-virginica   False
# 18  Iris-versicolor  Iris-versicolor    True
# 19   Iris-virginica   Iris-virginica    True
# 20      Iris-setosa      Iris-setosa    True
# 21   Iris-virginica   Iris-virginica    True
# 22      Iris-setosa      Iris-setosa    True
# 23   Iris-virginica   Iris-virginica    True
# 24   Iris-virginica   Iris-virginica    True
# 25   Iris-virginica   Iris-virginica    True
# 26   Iris-virginica   Iris-virginica    True
# 27   Iris-virginica   Iris-virginica    True
# 28      Iris-setosa      Iris-setosa    True
# 29      Iris-setosa      Iris-setosa    True
# 30      Iris-setosa      Iris-setosa    True
# 31      Iris-setosa      Iris-setosa    True
# 32  Iris-versicolor  Iris-versicolor    True
# 33      Iris-setosa      Iris-setosa    True
# 34      Iris-setosa      Iris-setosa    True
# 35   Iris-virginica  Iris-versicolor   False
# 36  Iris-versicolor  Iris-versicolor    True
# 37      Iris-setosa      Iris-setosa    True
# result
# True     35
# False     3
# Name: count, dtype: int64

# %%
35/38
# Out:
# 0.9210526315789473
