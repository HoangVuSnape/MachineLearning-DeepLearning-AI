# %% [markdown]
# # Exercise 1
# 1) Tìm hiểu phương pháp smoothing sử dụng trong mô hình ngôn ngữ, tập trung phương pháp Laplace
#
# 2) áp dụng mô hình ngôn ngữ 2-gram và 3-gram
#
# - Huấn luyện trên 1 tập corpus (tự thu thập)
#
# - Tính xác suất của 1 câu đưa vào (có sử dụng smoothing)

# %% [markdown]
# Smoothing methods in language models are used to reduce the phenomenon of "zero probability" for words that the model has never seen during training.
#
# ## Laplace smoothing
# Idea: To add a constant value to all the word counts in the dictionary. Specifically, we add one to all word counts, and then divide the numerator by the total number of possible words, including both the added words and the observed ones.
#
# $$ P(w_i \mid \text{class}) = \frac{\text{freq}(w_i, \text{class} ) + 1}{(N_{\text{class}} + V)} $$
#
# * N class = frequency of all words in class
# * V = number of unique words in vocabulary

# %% [markdown]
# ## Import Lib

# %%
# Lib
from utils import process_tweet, build_freqs
import nltk

import re
import string
import numpy as np

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer
from collections import Counter

# %% [markdown]
# ### Note:
# - nltk.FreqDist is the same Counter

# %% [markdown]
# ## Preprocessing

# %%
SOS = "<s> "
EOS = "</s>"
UNK = "<UNK>"

def add_sentence_tokens(sentences, n):
    """Wrap each sentence in SOS and EOS tokens.

    For n >= 2, n-1 SOS tokens are added, otherwise only one is added.

    Args:
        sentences (list of str): the sentences to wrap.
        n (int): order of the n-gram model which will use these sentences.
    Returns:
        List of sentences with SOS and EOS tokens wrapped around them.

    """
    sos = SOS * (n-1) if n > 1 else SOS
    return ['{}{} {}'.format(sos, s, EOS) for s in sentences]

def replace_singletons(tokens):
    """Replace tokens which appear only once in the corpus with <UNK>.
    
    Args:
        tokens (list of str): the tokens comprising the corpus.
    Returns:
        The same list of tokens with each singleton replaced by <UNK>.
    
    """
    vocab = nltk.FreqDist(tokens)
    return [token if vocab[token] > 1 else UNK for token in tokens]

def preprocess_1(sentences, n): # it have function replace singletons 
    """Add SOS/EOS/UNK tokens to given sentences and tokenize.

    Args:
        sentences (list of str): the sentences to preprocess.
        n (int): order of the n-gram model which will use these sentences.
    Returns:
        The preprocessed sentences, tokenized by words.

    """
    sentences = add_sentence_tokens(sentences, n)
    tokens = ' '.join(sentences).split(' ')
    tokens = replace_singletons(tokens)
    return tokens

def preprocess_2(sentences, n): #It haven't function replace sinletons
    """Add SOS/EOS/UNK tokens to given sentences and tokenize.

    Args:
        sentences (list of str): the sentences to preprocess.
        n (int): order of the n-gram model which will use these sentences.
    Returns:
        The preprocessed sentences, tokenized by words.

    """
    sentences = add_sentence_tokens(sentences, n)
    tokens = ' '.join(sentences).split(' ')
    return tokens

# %%
def generate_ngrams(tokens, n):
    """Generate n-grams from a list of tokens."""
    ngrams = []
    for i in range(len(tokens) - n + 1):
        ngram = ' '.join(tokens[i:i+n])
        ngrams.append(ngram)
    return ngrams

# %%
def build_ngram_model(tokens: list, n = 2): ## token , n -gram
    
    ngrams = list(nltk.ngrams(tokens, n))
    ngram_counts = Counter(ngrams)
    total_ngrams = len(ngram_counts)
    # Calculate Voca
    V = nltk.FreqDist(tokens)
    V_len = len(V)
    # print(ngram_counts)
    # Calculate probabilities
    ngram_probabilities = {ngram: (count+ 1) / (total_ngrams + V_len) for ngram, count in ngram_counts.items()}
    
    sorted_ngram_model = sorted(ngram_probabilities.items(), key=lambda x: x[1], reverse=True)
    return sorted_ngram_model 

def printNgram(ngram_model):
    for ngram, probability in ngram_model:
        print(f"{ngram}: {probability:.5f}")

# %% [markdown]
# ## Load data

# %%
# path = "data/train.txt"
path = "train.txt"
with open(path, 'r') as f:
    train = [l.strip() for l in f.readlines()]

# %% [markdown]
# ### Review

# %%
# train

# %%
# result_2gram = preprocess(train, 2)
# result_2gram
result_2gram = add_sentence_tokens(train, 2)
result_2gram
# Out:
# ['<s> liberty all star usa sets initial payout </s>',
#  '<s> we are being accused of not implementing this agreement </s>',
#  '<s> entregrowth closed at 135 dlrs and options at 55 cents </s>',
#  '<s> usda forecast south african 1986 87 corn exports at 210 mln tonnes vs 300 mln tonnes last month and 1985 86 exports at 275 mln tonnes vs 275 mln tonnes last month </s>',
#  '<s> norgolds issued capital will be 2405 mln shares of which 63 pct will be held by nbh after 89 mln are issued to shareholders to raise 196 mln dlrs it said </s>',
#  '<s> the april 6 sale to be evenly divided between the three and six month issues will result in a paydown of 165 billion dlrs as maturing bills total 1485 billion dlrs </s>',
#  '<s> waste managements tender offer announced before the opening today expires march 25 </s>',
#  '<s> he earlier estimated the damage from the us raid at about 500 mln dlrs </s>',
#  '<s> brougher bigi to sell 40 pct of subsidiary </s>',
#  '<s> that was not the case two years ago </s>',
#  '<s> cutrale and citrosuco officials were not immediately available for comment </s>',
#  '<s> the exchange market is apparently reacting too much and anyone who sold the dollar on the baker comment will regret it later on the bank of japan official told </s>',
#  '<s> it said intensifying competition in an environment of slow economic growth moodys predicts 25 pct worldwide growth in 1987 will lower returns and margins for many multinational firms </s>',
#  '<s> the payment date is april 8 and there will be a long first coupon period </s>',
#  '<s> shr 57 cts vs not given net 6889000 vs 107 mln nine mths shr 167 dlrs vs not given net 201 mln vs 230 mln note company went public in november 1986 </s>',
#  '<s> baker had said that west germany was apparently breaching the louvre accord </s>',
#  '<s> miniscribe corp said it filed with the securities and exchange commission a registration statement covering a 65 mln dlr issue of convertible subordinated debentures due 2012 </s>',
#  '<s> the us charges that the europeans are violating rules laid down in the 1979 agreement on trade in civil aircraft </s>',
#  '<s> the company did not name an underwriter for the sale </s>',
#  '<s> phelps dodge corp said it is calling for redemption on may one all of its five dlr convertible exchangeable preference shares at 5350 dlrs per share </s>',
#  '<s> this is not an attempt by squibb to become a major majority holder in cetus fildes told in an interview </s>',
#  '<s> the company said its board intendsd to schedule a meeting in the near future to review the proposal and it has asked oppenheimer and co inc to assist it in evaluating the offer and advise calny on its alternatives </s>']

# %%
tokens = ' '.join(result_2gram).split(' ')
# tokens

# %%
vocab = nltk.FreqDist(tokens)
vocab
# Out:
# FreqDist({'<s>': 22, '</s>': 22, 'the': 22, 'mln': 12, 'and': 11, 'in': 10, 'of': 8, 'to': 8, 'not': 7, 'dlrs': 7, ...})

# %%
result_cleaned = preprocess_2(train, 2)
len(result_cleaned)
# result_cleaned
# Out:
# 473

# %%
n_grams = nltk.ngrams(result_cleaned, 2)
n_vocab = nltk.FreqDist(n_grams)

m_grams = nltk.ngrams(result_cleaned, 1)
m_vocab = nltk.FreqDist(m_grams)

# %%
m_vocab
# Out:
# FreqDist({('<s>',): 22, ('</s>',): 22, ('the',): 22, ('mln',): 12, ('and',): 11, ('in',): 10, ('of',): 8, ('to',): 8, ('not',): 7, ('dlrs',): 7, ...})

# %%
n_vocab
# Out:
# FreqDist({('</s>', '<s>'): 21, ('<s>', 'the'): 6, ('mln', 'tonnes'): 4, ('will', 'be'): 3, ('exports', 'at'): 2, ('tonnes', 'vs'): 2, ('tonnes', 'last'): 2, ('last', 'month'): 2, ('275', 'mln'): 2, ('mln', 'dlrs'): 2, ...})

# %% [markdown]
# ## Run
# ### Module 2 gram

# %%
voca = nltk.FreqDist(result_cleaned)
type(voca)
# Out:
# nltk.probability.FreqDist

# %%
ngram_counts = Counter(result_cleaned)
len(ngram_counts)
# Out:
# 263

# %%
ngram_model = build_ngram_model(result_cleaned, n = 2)
# # Print the 2-gram model
# ngram_model
printNgram(ngram_model)
# Out:
# ('</s>', '<s>'): 0.03207
# ('<s>', 'the'): 0.01020
# ('mln', 'tonnes'): 0.00729
# ('will', 'be'): 0.00583
# ('exports', 'at'): 0.00437
# ('tonnes', 'vs'): 0.00437
# ('tonnes', 'last'): 0.00437
# ('last', 'month'): 0.00437
# ('275', 'mln'): 0.00437
# ('mln', 'dlrs'): 0.00437
# ('it', 'said'): 0.00437
# ('billion', 'dlrs'): 0.00437
# ('dlrs', '</s>'): 0.00437
# ('the', 'us'): 0.00437
# ('on', 'the'): 0.00437
# ('in', 'an'): 0.00437
# ('vs', 'not'): 0.00437
# ('not', 'given'): 0.00437
# ('given', 'net'): 0.00437
# ('corp', 'said'): 0.00437
# ('said', 'it'): 0.00437
# ('in', 'the'): 0.00437
# ('the', 'company'): 0.00437
# ('<s>', 'liberty'): 0.00292
# ('liberty', 'all'): 0.00292
# ('all', 'star'): 0.00292
# ('star', 'usa'): 0.00292
# ('usa', 'sets'): 0.00292
# ('sets', 'initial'): 0.00292
# ('initial', 'payout'): 0.00292
# ('payout', '</s>'): 0.00292
# ('<s>', 'we'): 0.00292
# ('we', 'are'): 0.00292
# ('are', 'being'): 0.00292
# ('being', 'accused'): 0.00292
# ('accused', 'of'): 0.00292
# ('of', 'not'): 0.00292
# ('not', 'implementing'): 0.00292
# ('implementing', 'this'): 0.00292
# ('this', 'agreement'): 0.00292
# ('agreement', '</s>'): 0.00292
# ('<s>', 'entregrowth'): 0.00292
# ('entregrowth', 'closed'): 0.00292
# ('closed', 'at'): 0.00292
# ('at', '135'): 0.00292
# ('135', 'dlrs'): 0.00292
# ('dlrs', 'and'): 0.00292
# ('and', 'options'): 0.00292
# ('options', 'at'): 0.00292
# ('at', '55'): 0.00292
# ('55', 'cents'): 0.00292
# ('cents', '</s>'): 0.00292
# ('has', 'asked'): 0.00292
# ('asked', 'oppenheimer'): 0.00292
# ('oppenheimer', 'and'): 0.00292
# ('and', 'co'): 0.00292
# ('co', 'inc'): 0.00292
# ('inc', 'to'): 0.00292
# ('to', 'assist'): 0.00292
# ('assist', 'it'): 0.00292
# ('it', 'in'): 0.00292
# ('in', 'evaluating'): 0.00292
# ('evaluating', 'the'): 0.00292
# ('the', 'offer'): 0.00292
# ('offer', 'and'): 0.00292
# ('and', 'advise'): 0.00292
# ('advise', 'calny'): 0.00292
# ('calny', 'on'): 0.00292
# ('on', 'its'): 0.00292
# ('its', 'alternatives'): 0.00292
# ('alternatives', '</s>'): 0.00292

# %% [markdown]
# ### Module 3 gram

# %%
ngram_model = build_ngram_model(result_cleaned, n = 3)
# # Print the 2-gram model
printNgram(ngram_model)
# Out:
# ('</s>', '<s>', 'the'): 0.00972
# ('mln', 'tonnes', 'vs'): 0.00417
# ('mln', 'tonnes', 'last'): 0.00417
# ('tonnes', 'last', 'month'): 0.00417
# ('275', 'mln', 'tonnes'): 0.00417
# ('dlrs', '</s>', '<s>'): 0.00417
# ('vs', 'not', 'given'): 0.00417
# ('not', 'given', 'net'): 0.00417
# ('corp', 'said', 'it'): 0.00417
# ('<s>', 'the', 'company'): 0.00417
# ('<s>', 'liberty', 'all'): 0.00278
# ('liberty', 'all', 'star'): 0.00278
# ('all', 'star', 'usa'): 0.00278
# ('star', 'usa', 'sets'): 0.00278
# ('usa', 'sets', 'initial'): 0.00278
# ('sets', 'initial', 'payout'): 0.00278
# ('initial', 'payout', '</s>'): 0.00278
# ('payout', '</s>', '<s>'): 0.00278
# ('</s>', '<s>', 'we'): 0.00278
# ('<s>', 'we', 'are'): 0.00278
# ('we', 'are', 'being'): 0.00278
# ('are', 'being', 'accused'): 0.00278
# ('being', 'accused', 'of'): 0.00278
# ('accused', 'of', 'not'): 0.00278
# ('of', 'not', 'implementing'): 0.00278
# ('not', 'implementing', 'this'): 0.00278
# ('implementing', 'this', 'agreement'): 0.00278
# ('this', 'agreement', '</s>'): 0.00278
# ('agreement', '</s>', '<s>'): 0.00278
# ('</s>', '<s>', 'entregrowth'): 0.00278
# ('<s>', 'entregrowth', 'closed'): 0.00278
# ('entregrowth', 'closed', 'at'): 0.00278
# ('closed', 'at', '135'): 0.00278
# ('at', '135', 'dlrs'): 0.00278
# ('135', 'dlrs', 'and'): 0.00278
# ('dlrs', 'and', 'options'): 0.00278
# ('and', 'options', 'at'): 0.00278
# ('options', 'at', '55'): 0.00278
# ('at', '55', 'cents'): 0.00278
# ('55', 'cents', '</s>'): 0.00278
# ('cents', '</s>', '<s>'): 0.00278
# ('</s>', '<s>', 'usda'): 0.00278
# ('<s>', 'usda', 'forecast'): 0.00278
# ('usda', 'forecast', 'south'): 0.00278
# ('forecast', 'south', 'african'): 0.00278
# ('south', 'african', '1986'): 0.00278
# ('african', '1986', '87'): 0.00278
# ('1986', '87', 'corn'): 0.00278
# ('87', 'corn', 'exports'): 0.00278
# ('corn', 'exports', 'at'): 0.00278
# ('exports', 'at', '210'): 0.00278
# ('at', '210', 'mln'): 0.00278
# ('210', 'mln', 'tonnes'): 0.00278
# ('tonnes', 'vs', '300'): 0.00278
# ('maturing', 'bills', 'total'): 0.00278
# ('bills', 'total', '1485'): 0.00278
# ('total', '1485', 'billion'): 0.00278
# ('1485', 'billion', 'dlrs'): 0.00278
# ('billion', 'dlrs', '</s>'): 0.00278
# ('</s>', '<s>', 'waste'): 0.00278
# ('<s>', 'waste', 'managements'): 0.00278
# ('waste', 'managements', 'tender'): 0.00278
# ('managements', 'tender', 'offer'): 0.00278
# ('tender', 'offer', 'announced'): 0.00278
# ('offer', 'announced', 'before'): 0.00278
# ('announced', 'before', 'the'): 0.00278
# ('before', 'the', 'opening'): 0.00278
# ('the', 'opening', 'today'): 0.00278
# ('opening', 'today', 'expires'): 0.00278
# ('today', 'expires', 'march'): 0.00278
# ('expires', 'march', '25'): 0.00278
# ('march', '25', '</s>'): 0.00278
# ('25', '</s>', '<s>'): 0.00278
# ('</s>', '<s>', 'he'): 0.00278
# ('<s>', 'he', 'earlier'): 0.00278
# ('he', 'earlier', 'estimated'): 0.00278
# ('earlier', 'estimated', 'the'): 0.00278
# ('estimated', 'the', 'damage'): 0.00278
# ('the', 'damage', 'from'): 0.00278
# ('damage', 'from', 'the'): 0.00278
# ('from', 'the', 'us'): 0.00278
# ('the', 'us', 'raid'): 0.00278
# ('us', 'raid', 'at'): 0.00278
# ('raid', 'at', 'about'): 0.00278
# ('at', 'about', '500'): 0.00278
# ('about', '500', 'mln'): 0.00278
# ('500', 'mln', 'dlrs'): 0.00278
# ('mln', 'dlrs', '</s>'): 0.00278
# ('</s>', '<s>', 'brougher'): 0.00278
# ('<s>', 'brougher', 'bigi'): 0.00278
# ('brougher', 'bigi', 'to'): 0.00278
# ('bigi', 'to', 'sell'): 0.00278
# ('to', 'sell', '40'): 0.00278
# ('sell', '40', 'pct'): 0.00278
# ('40', 'pct', 'of'): 0.00278
# ('pct', 'of', 'subsidiary'): 0.00278
# ('of', 'subsidiary', '</s>'): 0.00278
# ('subsidiary', '</s>', '<s>'): 0.00278
# ('</s>', '<s>', 'that'): 0.00278
# ('<s>', 'that', 'was'): 0.00278
# ('that', 'was', 'not'): 0.00278
# ('was', 'not', 'the'): 0.00278
# ('not', 'the', 'case'): 0.00278
# ('the', 'case', 'two'): 0.00278
# ('case', 'two', 'years'): 0.00278
# ('two', 'years', 'ago'): 0.00278
# ('years', 'ago', '</s>'): 0.00278
# ('ago', '</s>', '<s>'): 0.00278
# ('</s>', '<s>', 'cutrale'): 0.00278
# ('<s>', 'cutrale', 'and'): 0.00278
# ('cutrale', 'and', 'citrosuco'): 0.00278
# ('and', 'citrosuco', 'officials'): 0.00278
# ('citrosuco', 'officials', 'were'): 0.00278
# ('officials', 'were', 'not'): 0.00278
# ('were', 'not', 'immediately'): 0.00278
# ('not', 'immediately', 'available'): 0.00278
# ('immediately', 'available', 'for'): 0.00278
# ('available', 'for', 'comment'): 0.00278
# ('for', 'comment', '</s>'): 0.00278
# ('comment', '</s>', '<s>'): 0.00278
# ('<s>', 'the', 'exchange'): 0.00278
# ('the', 'exchange', 'market'): 0.00278
# ('exchange', 'market', 'is'): 0.00278
# ('market', 'is', 'apparently'): 0.00278
# ('is', 'apparently', 'reacting'): 0.00278
# ('apparently', 'reacting', 'too'): 0.00278
# ('in', 'cetus', 'fildes'): 0.00278
# ('cetus', 'fildes', 'told'): 0.00278
# ('fildes', 'told', 'in'): 0.00278
# ('told', 'in', 'an'): 0.00278
# ('in', 'an', 'interview'): 0.00278
# ('an', 'interview', '</s>'): 0.00278
# ('interview', '</s>', '<s>'): 0.00278
# ('the', 'company', 'said'): 0.00278
# ('company', 'said', 'its'): 0.00278
# ('said', 'its', 'board'): 0.00278
# ('its', 'board', 'intendsd'): 0.00278
# ('board', 'intendsd', 'to'): 0.00278
# ('intendsd', 'to', 'schedule'): 0.00278
# ('to', 'schedule', 'a'): 0.00278
# ('schedule', 'a', 'meeting'): 0.00278
# ('a', 'meeting', 'in'): 0.00278
# ('meeting', 'in', 'the'): 0.00278
# ('in', 'the', 'near'): 0.00278
# ('the', 'near', 'future'): 0.00278
# ('near', 'future', 'to'): 0.00278
# ('future', 'to', 'review'): 0.00278
# ('to', 'review', 'the'): 0.00278
# ('review', 'the', 'proposal'): 0.00278
# ('the', 'proposal', 'and'): 0.00278
# ('proposal', 'and', 'it'): 0.00278
# ('and', 'it', 'has'): 0.00278
# ('it', 'has', 'asked'): 0.00278
# ('has', 'asked', 'oppenheimer'): 0.00278
# ('asked', 'oppenheimer', 'and'): 0.00278
# ('oppenheimer', 'and', 'co'): 0.00278
# ('and', 'co', 'inc'): 0.00278
# ('co', 'inc', 'to'): 0.00278
# ('inc', 'to', 'assist'): 0.00278
# ('to', 'assist', 'it'): 0.00278
# ('assist', 'it', 'in'): 0.00278
# ('it', 'in', 'evaluating'): 0.00278
# ('in', 'evaluating', 'the'): 0.00278
# ('evaluating', 'the', 'offer'): 0.00278
# ('the', 'offer', 'and'): 0.00278
# ('offer', 'and', 'advise'): 0.00278
# ('and', 'advise', 'calny'): 0.00278
# ('advise', 'calny', 'on'): 0.00278
# ('calny', 'on', 'its'): 0.00278
# ('on', 'its', 'alternatives'): 0.00278
# ('its', 'alternatives', '</s>'): 0.00278

# %% [markdown]
# ## Write OOP

# %%
# path = "data/train.txt"
path = "train.txt"
with open(path, 'r') as f:
    train = [l.strip() for l in f.readlines()]

# %%
class NGramLanguageModel(object):
    """An n-gram language model trained on a given corpus.
    
    For a given n and given training corpus, constructs an n-gram language
    model for the corpus by:
    1. preprocessing the corpus (adding SOS/EOS/UNK tokens)
    2. calculating (smoothed) probabilities for each n-gram

    Also contains methods for calculating the perplexity of the model
    against another corpus, and for generating sentences.

    Args:
        train_data (list of str): list of sentences comprising the training corpus.
        n (int): the order of language model to build (i.e. 1 for unigram, 2 for bigram, etc.).
        laplace (int): lambda multiplier to use for laplace smoothing (default 1 for add-1 smoothing).

    """
    def __init__(self, train_data, n, laplace=1) -> None:
        self.n = n
        self.laplace = laplace
        self.tokens = preprocess_2(train_data, n)
        self.vocab = nltk.FreqDist(self.tokens)  # word, times
        self.model = self._create_model()
    
    def _smooth(self):
        """Apply Laplace smoothing to n-gram frequency distribution.
        
        Here, n_grams refers to the n-grams of the tokens in the training corpus,
        while m_grams refers to the first (n-1) tokens of each n-gram.

        Returns:
            dict: Mapping of each n-gram (tuple of str) to its Laplace-smoothed 
            probability (float).

        """
        vocab_size = len(self.vocab)
        
        n_grams = nltk.ngrams(self.tokens, self.n)
        n_vocab = nltk.FreqDist(n_grams)
        
        m_grams = nltk.ngrams(self.tokens, self.n - 1)
        m_vocab = nltk.FreqDist(m_grams)
        
        def smoothed_count(n_gram, n_count):
            m_gram = n_gram[:-1]
            m_count = m_vocab[m_gram]
            return (n_count + self.laplace) / (m_count + self.laplace * vocab_size)
        
        return {n_gram: smoothed_count(n_gram, count) for n_gram, count in n_vocab.items()}
        
    def _create_model(self):       
        """Create a probability distribution for the vocabulary of the training corpus.
        
        If building a unigram model, the probabilities are simple relative frequencies
        of each token with the entire corpus.

        Otherwise, the probabilities are Laplace-smoothed relative frequencies.

        Returns:
            A dict mapping each n-gram (tuple of str) to its probability (float).

        """
        if self.n == 1:
            num_tokens = len(self.tokens)
            return {(unigram,): count/ num_tokens for unigram, count in self.vocab.items()}
        else: 
            return self._smooth()

# %% [markdown]
# ## Run code
# ### Model 2, 3 Gram
# - calcualte probabblity of corpus

# %%
lm_2gram = NGramLanguageModel(train, 2, 1)

lm_2gram.model
# Out:
# {('<s>', 'liberty'): 0.007017543859649123,
#  ('liberty', 'all'): 0.007575757575757576,
#  ('all', 'star'): 0.007547169811320755,
#  ('star', 'usa'): 0.007575757575757576,
#  ('usa', 'sets'): 0.007575757575757576,
#  ('sets', 'initial'): 0.007575757575757576,
#  ('initial', 'payout'): 0.007575757575757576,
#  ('payout', '</s>'): 0.007575757575757576,
#  ('</s>', '<s>'): 0.07719298245614035,
#  ('<s>', 'we'): 0.007017543859649123,
#  ('we', 'are'): 0.007575757575757576,
#  ('are', 'being'): 0.007518796992481203,
#  ('being', 'accused'): 0.007575757575757576,
#  ('accused', 'of'): 0.007575757575757576,
#  ('of', 'not'): 0.007380073800738007,
#  ('not', 'implementing'): 0.007407407407407408,
#  ('implementing', 'this'): 0.007575757575757576,
#  ('this', 'agreement'): 0.007547169811320755,
#  ('agreement', '</s>'): 0.007547169811320755,
#  ('<s>', 'entregrowth'): 0.007017543859649123,
#  ('entregrowth', 'closed'): 0.007575757575757576,
#  ('closed', 'at'): 0.007575757575757576,
#  ('at', '135'): 0.007434944237918215,
#  ('135', 'dlrs'): 0.007575757575757576,
#  ('dlrs', 'and'): 0.007407407407407408,
#  ('and', 'options'): 0.0072992700729927005,
#  ('options', 'at'): 0.007575757575757576,
#  ('at', '55'): 0.007434944237918215,
#  ('55', 'cents'): 0.007575757575757576,
#  ('cents', '</s>'): 0.007575757575757576,
#  ('<s>', 'usda'): 0.007017543859649123,
#  ('usda', 'forecast'): 0.007575757575757576,
#  ('forecast', 'south'): 0.007575757575757576,
#  ('south', 'african'): 0.007575757575757576,
#  ('african', '1986'): 0.007575757575757576,
#  ('1986', '87'): 0.007547169811320755,
#  ('87', 'corn'): 0.007575757575757576,
#  ('corn', 'exports'): 0.007575757575757576,
#  ('exports', 'at'): 0.011320754716981131,
#  ('at', '210'): 0.007434944237918215,
#  ('210', 'mln'): 0.007575757575757576,
#  ('mln', 'tonnes'): 0.01818181818181818,
#  ('tonnes', 'vs'): 0.011235955056179775,
#  ('vs', '300'): 0.007434944237918215,
#  ('300', 'mln'): 0.007575757575757576,
#  ('tonnes', 'last'): 0.011235955056179775,
#  ('last', 'month'): 0.011320754716981131,
#  ('month', 'and'): 0.007518796992481203,
#  ('and', '1985'): 0.0072992700729927005,
#  ('1985', '86'): 0.007575757575757576,
#  ('86', 'exports'): 0.007575757575757576,
#  ('at', '275'): 0.007434944237918215,
#  ('275', 'mln'): 0.011320754716981131,
#  ('vs', '275'): 0.007434944237918215,
#  ('month', '</s>'): 0.007518796992481203,
#  ('<s>', 'norgolds'): 0.007017543859649123,
#  ('norgolds', 'issued'): 0.007575757575757576,
#  ('issued', 'capital'): 0.007547169811320755,
#  ('capital', 'will'): 0.007575757575757576,
#  ('will', 'be'): 0.01486988847583643,
#  ('be', '2405'): 0.00749063670411985,
#  ('2405', 'mln'): 0.007575757575757576,
#  ('mln', 'shares'): 0.007272727272727273,
#  ('shares', 'of'): 0.007547169811320755,
#  ('of', 'which'): 0.007380073800738007,
#  ('which', '63'): 0.007575757575757576,
#  ('63', 'pct'): 0.007575757575757576,
#  ('pct', 'will'): 0.007518796992481203,
#  ('be', 'held'): 0.00749063670411985,
#  ('held', 'by'): 0.007575757575757576,
#  ('by', 'nbh'): 0.007547169811320755,
#  ('nbh', 'after'): 0.007575757575757576,
#  ('after', '89'): 0.007575757575757576,
#  ('89', 'mln'): 0.007575757575757576,
#  ('mln', 'are'): 0.007272727272727273,
#  ('are', 'issued'): 0.007518796992481203,
#  ('issued', 'to'): 0.007547169811320755,
#  ('to', 'shareholders'): 0.007380073800738007,
#  ('shareholders', 'to'): 0.007575757575757576,
#  ('to', 'raise'): 0.007380073800738007,
#  ('raise', '196'): 0.007575757575757576,
#  ('196', 'mln'): 0.007575757575757576,
#  ('mln', 'dlrs'): 0.01090909090909091,
#  ('dlrs', 'it'): 0.007407407407407408,
#  ('it', 'said'): 0.011111111111111112,
#  ('said', '</s>'): 0.007434944237918215,
#  ('<s>', 'the'): 0.02456140350877193,
#  ('the', 'april'): 0.007017543859649123,
#  ('april', '6'): 0.007547169811320755,
#  ('6', 'sale'): 0.007575757575757576,
#  ('sale', 'to'): 0.007547169811320755,
#  ('to', 'be'): 0.007380073800738007,
#  ('be', 'evenly'): 0.00749063670411985,
#  ('evenly', 'divided'): 0.007575757575757576,
#  ('divided', 'between'): 0.007575757575757576,
#  ('between', 'the'): 0.007575757575757576,
#  ('the', 'three'): 0.007017543859649123,
#  ('three', 'and'): 0.007575757575757576,
#  ('and', 'six'): 0.0072992700729927005,
#  ('six', 'month'): 0.007575757575757576,
#  ('month', 'issues'): 0.007518796992481203,
#  ('issues', 'will'): 0.007575757575757576,
#  ('will', 'result'): 0.007434944237918215,
#  ('result', 'in'): 0.007575757575757576,
#  ('in', 'a'): 0.007326007326007326,
#  ('a', 'paydown'): 0.007434944237918215,
#  ('paydown', 'of'): 0.007575757575757576,
#  ('of', '165'): 0.007380073800738007,
#  ('165', 'billion'): 0.007575757575757576,
#  ('billion', 'dlrs'): 0.011320754716981131,
#  ('dlrs', 'as'): 0.007407407407407408,
#  ('as', 'maturing'): 0.007575757575757576,
#  ('maturing', 'bills'): 0.007575757575757576,
#  ('bills', 'total'): 0.007575757575757576,
#  ('total', '1485'): 0.007575757575757576,
#  ('1485', 'billion'): 0.007575757575757576,
#  ('dlrs', '</s>'): 0.011111111111111112,
#  ('<s>', 'waste'): 0.007017543859649123,
#  ('waste', 'managements'): 0.007575757575757576,
#  ('managements', 'tender'): 0.007575757575757576,
#  ('tender', 'offer'): 0.007575757575757576,
#  ('offer', 'announced'): 0.007547169811320755,
#  ('announced', 'before'): 0.007575757575757576,
#  ('before', 'the'): 0.007575757575757576,
#  ('the', 'opening'): 0.007017543859649123,
#  ('opening', 'today'): 0.007575757575757576,
#  ('today', 'expires'): 0.007575757575757576,
#  ('expires', 'march'): 0.007575757575757576,
#  ('march', '25'): 0.007575757575757576,
#  ('25', '</s>'): 0.007547169811320755,
#  ('<s>', 'he'): 0.007017543859649123,
#  ('he', 'earlier'): 0.007575757575757576,
#  ('earlier', 'estimated'): 0.007575757575757576,
#  ('estimated', 'the'): 0.007575757575757576,
#  ('the', 'damage'): 0.007017543859649123,
#  ('damage', 'from'): 0.007575757575757576,
#  ('from', 'the'): 0.007575757575757576,
#  ('the', 'us'): 0.010526315789473684,
#  ('us', 'raid'): 0.007547169811320755,
#  ('raid', 'at'): 0.007575757575757576,
#  ('at', 'about'): 0.007434944237918215,
#  ('about', '500'): 0.007575757575757576,
#  ('500', 'mln'): 0.007575757575757576,
#  ('<s>', 'brougher'): 0.007017543859649123,
#  ('brougher', 'bigi'): 0.007575757575757576,
#  ('bigi', 'to'): 0.007575757575757576,
#  ('to', 'sell'): 0.007380073800738007,
#  ('sell', '40'): 0.007575757575757576,
#  ('40', 'pct'): 0.007575757575757576,
#  ('pct', 'of'): 0.007518796992481203,
#  ('of', 'subsidiary'): 0.007380073800738007,
#  ('subsidiary', '</s>'): 0.007575757575757576,
#  ('<s>', 'that'): 0.007017543859649123,
#  ('that', 'was'): 0.007518796992481203,
#  ('was', 'not'): 0.007547169811320755,
#  ('not', 'the'): 0.007407407407407408,
#  ('the', 'case'): 0.007017543859649123,
#  ('case', 'two'): 0.007575757575757576,
#  ('two', 'years'): 0.007575757575757576,
#  ('years', 'ago'): 0.007575757575757576,
#  ('ago', '</s>'): 0.007575757575757576,
#  ('<s>', 'cutrale'): 0.007017543859649123,
#  ('cutrale', 'and'): 0.007575757575757576,
#  ('and', 'citrosuco'): 0.0072992700729927005,
#  ('citrosuco', 'officials'): 0.007575757575757576,
#  ('officials', 'were'): 0.007575757575757576,
#  ('were', 'not'): 0.007575757575757576,
#  ('not', 'immediately'): 0.007407407407407408,
#  ('immediately', 'available'): 0.007575757575757576,
#  ('available', 'for'): 0.007575757575757576,
#  ('for', 'comment'): 0.00749063670411985,
#  ('comment', '</s>'): 0.007547169811320755,
#  ('the', 'exchange'): 0.007017543859649123,
#  ('exchange', 'market'): 0.007547169811320755,
#  ('market', 'is'): 0.007575757575757576,
#  ('is', 'apparently'): 0.00749063670411985,
#  ('apparently', 'reacting'): 0.007547169811320755,
#  ('reacting', 'too'): 0.007575757575757576,
#  ('too', 'much'): 0.007575757575757576,
#  ('much', 'and'): 0.007575757575757576,
#  ('and', 'anyone'): 0.0072992700729927005,
#  ('anyone', 'who'): 0.007575757575757576,
#  ('who', 'sold'): 0.007575757575757576,
#  ('sold', 'the'): 0.007575757575757576,
#  ('the', 'dollar'): 0.007017543859649123,
#  ('dollar', 'on'): 0.007575757575757576,
#  ('on', 'the'): 0.011194029850746268,
#  ('the', 'baker'): 0.007017543859649123,
#  ('baker', 'comment'): 0.007547169811320755,
#  ('comment', 'will'): 0.007547169811320755,
#  ('will', 'regret'): 0.007434944237918215,
#  ('regret', 'it'): 0.007575757575757576,
#  ('it', 'later'): 0.007407407407407408,
#  ('later', 'on'): 0.007575757575757576,
#  ('the', 'bank'): 0.007017543859649123,
#  ('bank', 'of'): 0.007575757575757576,
#  ('of', 'japan'): 0.007380073800738007,
#  ('japan', 'official'): 0.007575757575757576,
#  ('official', 'told'): 0.007575757575757576,
#  ('told', '</s>'): 0.007547169811320755,
#  ('<s>', 'it'): 0.007017543859649123,
#  ('said', 'intensifying'): 0.007434944237918215,
#  ('intensifying', 'competition'): 0.007575757575757576,
#  ('competition', 'in'): 0.007575757575757576,
#  ('in', 'an'): 0.01098901098901099,
#  ('an', 'environment'): 0.00749063670411985,
#  ('environment', 'of'): 0.007575757575757576,
#  ('of', 'slow'): 0.007380073800738007,
#  ('slow', 'economic'): 0.007575757575757576,
#  ('economic', 'growth'): 0.007575757575757576,
#  ('growth', 'moodys'): 0.007547169811320755,
#  ('moodys', 'predicts'): 0.007575757575757576,
#  ('predicts', '25'): 0.007575757575757576,
#  ('25', 'pct'): 0.007547169811320755,
#  ('pct', 'worldwide'): 0.007518796992481203,
#  ('worldwide', 'growth'): 0.007575757575757576,
#  ('growth', 'in'): 0.007547169811320755,
#  ('in', '1987'): 0.007326007326007326,
#  ('1987', 'will'): 0.007575757575757576,
#  ('will', 'lower'): 0.007434944237918215,
#  ('lower', 'returns'): 0.007575757575757576,
#  ('returns', 'and'): 0.007575757575757576,
#  ('and', 'margins'): 0.0072992700729927005,
#  ('margins', 'for'): 0.007575757575757576,
#  ('for', 'many'): 0.00749063670411985,
#  ('many', 'multinational'): 0.007575757575757576,
#  ('multinational', 'firms'): 0.007575757575757576,
#  ('firms', '</s>'): 0.007575757575757576,
#  ('the', 'payment'): 0.007017543859649123,
#  ('payment', 'date'): 0.007575757575757576,
#  ('date', 'is'): 0.007575757575757576,
#  ('is', 'april'): 0.00749063670411985,
#  ('april', '8'): 0.007547169811320755,
#  ('8', 'and'): 0.007575757575757576,
#  ('and', 'there'): 0.0072992700729927005,
#  ('there', 'will'): 0.007575757575757576,
#  ('be', 'a'): 0.00749063670411985,
#  ('a', 'long'): 0.007434944237918215,
#  ('long', 'first'): 0.007575757575757576,
#  ('first', 'coupon'): 0.007575757575757576,
#  ('coupon', 'period'): 0.007575757575757576,
#  ('period', '</s>'): 0.007575757575757576,
#  ('<s>', 'shr'): 0.007017543859649123,
#  ('shr', '57'): 0.007547169811320755,
#  ('57', 'cts'): 0.007575757575757576,
#  ('cts', 'vs'): 0.007575757575757576,
#  ('vs', 'not'): 0.011152416356877323,
#  ('not', 'given'): 0.011111111111111112,
#  ('given', 'net'): 0.011320754716981131,
#  ('net', '6889000'): 0.007547169811320755,
#  ('6889000', 'vs'): 0.007575757575757576,
#  ('vs', '107'): 0.007434944237918215,
#  ('107', 'mln'): 0.007575757575757576,
#  ('mln', 'nine'): 0.007272727272727273,
#  ('nine', 'mths'): 0.007575757575757576,
#  ('mths', 'shr'): 0.007575757575757576,
#  ('shr', '167'): 0.007547169811320755,
#  ('167', 'dlrs'): 0.007575757575757576,
#  ('dlrs', 'vs'): 0.007407407407407408,
#  ('net', '201'): 0.007547169811320755,
#  ('201', 'mln'): 0.007575757575757576,
#  ('mln', 'vs'): 0.007272727272727273,
#  ('vs', '230'): 0.007434944237918215,
#  ('230', 'mln'): 0.007575757575757576,
#  ('mln', 'note'): 0.007272727272727273,
#  ('note', 'company'): 0.007575757575757576,
#  ('company', 'went'): 0.007518796992481203,
#  ('went', 'public'): 0.007575757575757576,
#  ('public', 'in'): 0.007575757575757576,
#  ('in', 'november'): 0.007326007326007326,
#  ('november', '1986'): 0.007575757575757576,
#  ('1986', '</s>'): 0.007547169811320755,
#  ('<s>', 'baker'): 0.007017543859649123,
#  ('baker', 'had'): 0.007547169811320755,
#  ('had', 'said'): 0.007575757575757576,
#  ('said', 'that'): 0.007434944237918215,
#  ('that', 'west'): 0.007518796992481203,
#  ('west', 'germany'): 0.007575757575757576,
#  ('germany', 'was'): 0.007575757575757576,
#  ('was', 'apparently'): 0.007547169811320755,
#  ('apparently', 'breaching'): 0.007547169811320755,
#  ('breaching', 'the'): 0.007575757575757576,
#  ('the', 'louvre'): 0.007017543859649123,
#  ('louvre', 'accord'): 0.007575757575757576,
#  ('accord', '</s>'): 0.007575757575757576,
#  ('<s>', 'miniscribe'): 0.007017543859649123,
#  ('miniscribe', 'corp'): 0.007575757575757576,
#  ('corp', 'said'): 0.011320754716981131,
#  ('said', 'it'): 0.011152416356877323,
#  ('it', 'filed'): 0.007407407407407408,
#  ('filed', 'with'): 0.007575757575757576,
#  ('with', 'the'): 0.007575757575757576,
#  ('the', 'securities'): 0.007017543859649123,
#  ('securities', 'and'): 0.007575757575757576,
#  ('and', 'exchange'): 0.0072992700729927005,
#  ('exchange', 'commission'): 0.007547169811320755,
#  ('commission', 'a'): 0.007575757575757576,
#  ('a', 'registration'): 0.007434944237918215,
#  ('registration', 'statement'): 0.007575757575757576,
#  ('statement', 'covering'): 0.007575757575757576,
#  ('covering', 'a'): 0.007575757575757576,
#  ('a', '65'): 0.007434944237918215,
#  ('65', 'mln'): 0.007575757575757576,
#  ('mln', 'dlr'): 0.007272727272727273,
#  ('dlr', 'issue'): 0.007547169811320755,
#  ('issue', 'of'): 0.007575757575757576,
#  ('of', 'convertible'): 0.007380073800738007,
#  ('convertible', 'subordinated'): 0.007547169811320755,
#  ('subordinated', 'debentures'): 0.007575757575757576,
#  ('debentures', 'due'): 0.007575757575757576,
#  ('due', '2012'): 0.007575757575757576,
#  ('2012', '</s>'): 0.007575757575757576,
#  ('us', 'charges'): 0.007547169811320755,
#  ('charges', 'that'): 0.007575757575757576,
#  ('that', 'the'): 0.007518796992481203,
#  ('the', 'europeans'): 0.007017543859649123,
#  ('europeans', 'are'): 0.007575757575757576,
#  ('are', 'violating'): 0.007518796992481203,
#  ('violating', 'rules'): 0.007575757575757576,
#  ('rules', 'laid'): 0.007575757575757576,
#  ('laid', 'down'): 0.007575757575757576,
#  ('down', 'in'): 0.007575757575757576,
#  ('in', 'the'): 0.01098901098901099,
#  ('the', '1979'): 0.007017543859649123,
#  ('1979', 'agreement'): 0.007575757575757576,
#  ('agreement', 'on'): 0.007547169811320755,
#  ('on', 'trade'): 0.007462686567164179,
#  ('trade', 'in'): 0.007575757575757576,
#  ('in', 'civil'): 0.007326007326007326,
#  ('civil', 'aircraft'): 0.007575757575757576,
#  ('aircraft', '</s>'): 0.007575757575757576,
#  ('the', 'company'): 0.010526315789473684,
#  ('company', 'did'): 0.007518796992481203,
#  ('did', 'not'): 0.007575757575757576,
#  ('not', 'name'): 0.007407407407407408,
#  ('name', 'an'): 0.007575757575757576,
#  ('an', 'underwriter'): 0.00749063670411985,
#  ('underwriter', 'for'): 0.007575757575757576,
#  ('for', 'the'): 0.00749063670411985,
#  ('the', 'sale'): 0.007017543859649123,
#  ('sale', '</s>'): 0.007547169811320755,
#  ('<s>', 'phelps'): 0.007017543859649123,
#  ('phelps', 'dodge'): 0.007575757575757576,
#  ('dodge', 'corp'): 0.007575757575757576,
#  ('it', 'is'): 0.007407407407407408,
#  ('is', 'calling'): 0.00749063670411985,
#  ('calling', 'for'): 0.007575757575757576,
#  ('for', 'redemption'): 0.00749063670411985,
#  ('redemption', 'on'): 0.007575757575757576,
#  ('on', 'may'): 0.007462686567164179,
#  ('may', 'one'): 0.007575757575757576,
#  ('one', 'all'): 0.007575757575757576,
#  ('all', 'of'): 0.007547169811320755,
#  ('of', 'its'): 0.007380073800738007,
#  ('its', 'five'): 0.007518796992481203,
#  ('five', 'dlr'): 0.007575757575757576,
#  ('dlr', 'convertible'): 0.007547169811320755,
#  ('convertible', 'exchangeable'): 0.007547169811320755,
#  ('exchangeable', 'preference'): 0.007575757575757576,
#  ('preference', 'shares'): 0.007575757575757576,
#  ('shares', 'at'): 0.007547169811320755,
#  ('at', '5350'): 0.007434944237918215,
#  ('5350', 'dlrs'): 0.007575757575757576,
#  ('dlrs', 'per'): 0.007407407407407408,
#  ('per', 'share'): 0.007575757575757576,
#  ('share', '</s>'): 0.007575757575757576,
#  ('<s>', 'this'): 0.007017543859649123,
#  ('this', 'is'): 0.007547169811320755,
#  ('is', 'not'): 0.00749063670411985,
#  ('not', 'an'): 0.007407407407407408,
#  ('an', 'attempt'): 0.00749063670411985,
#  ('attempt', 'by'): 0.007575757575757576,
#  ('by', 'squibb'): 0.007547169811320755,
#  ('squibb', 'to'): 0.007575757575757576,
#  ('to', 'become'): 0.007380073800738007,
#  ('become', 'a'): 0.007575757575757576,
#  ('a', 'major'): 0.007434944237918215,
#  ('major', 'majority'): 0.007575757575757576,
#  ('majority', 'holder'): 0.007575757575757576,
#  ('holder', 'in'): 0.007575757575757576,
#  ('in', 'cetus'): 0.007326007326007326,
#  ('cetus', 'fildes'): 0.007575757575757576,
#  ('fildes', 'told'): 0.007575757575757576,
#  ('told', 'in'): 0.007547169811320755,
#  ('an', 'interview'): 0.00749063670411985,
#  ('interview', '</s>'): 0.007575757575757576,
#  ('company', 'said'): 0.007518796992481203,
#  ('said', 'its'): 0.007434944237918215,
#  ('its', 'board'): 0.007518796992481203,
#  ('board', 'intendsd'): 0.007575757575757576,
#  ('intendsd', 'to'): 0.007575757575757576,
#  ('to', 'schedule'): 0.007380073800738007,
#  ('schedule', 'a'): 0.007575757575757576,
#  ('a', 'meeting'): 0.007434944237918215,
#  ('meeting', 'in'): 0.007575757575757576,
#  ('the', 'near'): 0.007017543859649123,
#  ('near', 'future'): 0.007575757575757576,
#  ('future', 'to'): 0.007575757575757576,
#  ('to', 'review'): 0.007380073800738007,
#  ('review', 'the'): 0.007575757575757576,
#  ('the', 'proposal'): 0.007017543859649123,
#  ('proposal', 'and'): 0.007575757575757576,
#  ('and', 'it'): 0.0072992700729927005,
#  ('it', 'has'): 0.007407407407407408,
#  ('has', 'asked'): 0.007575757575757576,
#  ('asked', 'oppenheimer'): 0.007575757575757576,
#  ('oppenheimer', 'and'): 0.007575757575757576,
#  ('and', 'co'): 0.0072992700729927005,
#  ('co', 'inc'): 0.007575757575757576,
#  ('inc', 'to'): 0.007575757575757576,
#  ('to', 'assist'): 0.007380073800738007,
#  ('assist', 'it'): 0.007575757575757576,
#  ('it', 'in'): 0.007407407407407408,
#  ('in', 'evaluating'): 0.007326007326007326,
#  ('evaluating', 'the'): 0.007575757575757576,
#  ('the', 'offer'): 0.007017543859649123,
#  ('offer', 'and'): 0.007547169811320755,
#  ('and', 'advise'): 0.0072992700729927005,
#  ('advise', 'calny'): 0.007575757575757576,
#  ('calny', 'on'): 0.007575757575757576,
#  ('on', 'its'): 0.007462686567164179,
#  ('its', 'alternatives'): 0.007518796992481203,
#  ('alternatives', '</s>'): 0.007575757575757576}

# %% [markdown]
# #### 3 Gram

# %%
lm_3gram = NGramLanguageModel(train, 3, 1)

lm_3gram.model
# Out:
# {('<s>', '<s>', 'liberty'): 0.007017543859649123,
#  ('<s>', 'liberty', 'all'): 0.007575757575757576,
#  ('liberty', 'all', 'star'): 0.007575757575757576,
#  ('all', 'star', 'usa'): 0.007575757575757576,
#  ('star', 'usa', 'sets'): 0.007575757575757576,
#  ('usa', 'sets', 'initial'): 0.007575757575757576,
#  ('sets', 'initial', 'payout'): 0.007575757575757576,
#  ('initial', 'payout', '</s>'): 0.007575757575757576,
#  ('payout', '</s>', '<s>'): 0.007575757575757576,
#  ('</s>', '<s>', '<s>'): 0.07746478873239436,
#  ('<s>', '<s>', 'we'): 0.007017543859649123,
#  ('<s>', 'we', 'are'): 0.007575757575757576,
#  ('we', 'are', 'being'): 0.007575757575757576,
#  ('are', 'being', 'accused'): 0.007575757575757576,
#  ('being', 'accused', 'of'): 0.007575757575757576,
#  ('accused', 'of', 'not'): 0.007575757575757576,
#  ('of', 'not', 'implementing'): 0.007575757575757576,
#  ('not', 'implementing', 'this'): 0.007575757575757576,
#  ('implementing', 'this', 'agreement'): 0.007575757575757576,
#  ('this', 'agreement', '</s>'): 0.007575757575757576,
#  ('agreement', '</s>', '<s>'): 0.007575757575757576,
#  ('<s>', '<s>', 'entregrowth'): 0.007017543859649123,
#  ('<s>', 'entregrowth', 'closed'): 0.007575757575757576,
#  ('entregrowth', 'closed', 'at'): 0.007575757575757576,
#  ('closed', 'at', '135'): 0.007575757575757576,
#  ('at', '135', 'dlrs'): 0.007575757575757576,
#  ('135', 'dlrs', 'and'): 0.007575757575757576,
#  ('dlrs', 'and', 'options'): 0.007575757575757576,
#  ('and', 'options', 'at'): 0.007575757575757576,
#  ('options', 'at', '55'): 0.007575757575757576,
#  ('at', '55', 'cents'): 0.007575757575757576,
#  ('55', 'cents', '</s>'): 0.007575757575757576,
#  ('cents', '</s>', '<s>'): 0.007575757575757576,
#  ('<s>', '<s>', 'usda'): 0.007017543859649123,
#  ('<s>', 'usda', 'forecast'): 0.007575757575757576,
#  ('usda', 'forecast', 'south'): 0.007575757575757576,
#  ('forecast', 'south', 'african'): 0.007575757575757576,
#  ('south', 'african', '1986'): 0.007575757575757576,
#  ('african', '1986', '87'): 0.007575757575757576,
#  ('1986', '87', 'corn'): 0.007575757575757576,
#  ('87', 'corn', 'exports'): 0.007575757575757576,
#  ('corn', 'exports', 'at'): 0.007575757575757576,
#  ('exports', 'at', '210'): 0.007547169811320755,
#  ('at', '210', 'mln'): 0.007575757575757576,
#  ('210', 'mln', 'tonnes'): 0.007575757575757576,
#  ('mln', 'tonnes', 'vs'): 0.011235955056179775,
#  ('tonnes', 'vs', '300'): 0.007547169811320755,
#  ('vs', '300', 'mln'): 0.007575757575757576,
#  ('300', 'mln', 'tonnes'): 0.007575757575757576,
#  ('mln', 'tonnes', 'last'): 0.011235955056179775,
#  ('tonnes', 'last', 'month'): 0.011320754716981131,
#  ('last', 'month', 'and'): 0.007547169811320755,
#  ('month', 'and', '1985'): 0.007575757575757576,
#  ('and', '1985', '86'): 0.007575757575757576,
#  ('1985', '86', 'exports'): 0.007575757575757576,
#  ('86', 'exports', 'at'): 0.007575757575757576,
#  ('exports', 'at', '275'): 0.007547169811320755,
#  ('at', '275', 'mln'): 0.007575757575757576,
#  ('275', 'mln', 'tonnes'): 0.011320754716981131,
#  ('tonnes', 'vs', '275'): 0.007547169811320755,
#  ('vs', '275', 'mln'): 0.007575757575757576,
#  ('last', 'month', '</s>'): 0.007547169811320755,
#  ('month', '</s>', '<s>'): 0.007575757575757576,
#  ('<s>', '<s>', 'norgolds'): 0.007017543859649123,
#  ('<s>', 'norgolds', 'issued'): 0.007575757575757576,
#  ('norgolds', 'issued', 'capital'): 0.007575757575757576,
#  ('issued', 'capital', 'will'): 0.007575757575757576,
#  ('capital', 'will', 'be'): 0.007575757575757576,
#  ('will', 'be', '2405'): 0.007518796992481203,
#  ('be', '2405', 'mln'): 0.007575757575757576,
#  ('2405', 'mln', 'shares'): 0.007575757575757576,
#  ('mln', 'shares', 'of'): 0.007575757575757576,
#  ('shares', 'of', 'which'): 0.007575757575757576,
#  ('of', 'which', '63'): 0.007575757575757576,
#  ('which', '63', 'pct'): 0.007575757575757576,
#  ('63', 'pct', 'will'): 0.007575757575757576,
#  ('pct', 'will', 'be'): 0.007575757575757576,
#  ('will', 'be', 'held'): 0.007518796992481203,
#  ('be', 'held', 'by'): 0.007575757575757576,
#  ('held', 'by', 'nbh'): 0.007575757575757576,
#  ('by', 'nbh', 'after'): 0.007575757575757576,
#  ('nbh', 'after', '89'): 0.007575757575757576,
#  ('after', '89', 'mln'): 0.007575757575757576,
#  ('89', 'mln', 'are'): 0.007575757575757576,
#  ('mln', 'are', 'issued'): 0.007575757575757576,
#  ('are', 'issued', 'to'): 0.007575757575757576,
#  ('issued', 'to', 'shareholders'): 0.007575757575757576,
#  ('to', 'shareholders', 'to'): 0.007575757575757576,
#  ('shareholders', 'to', 'raise'): 0.007575757575757576,
#  ('to', 'raise', '196'): 0.007575757575757576,
#  ('raise', '196', 'mln'): 0.007575757575757576,
#  ('196', 'mln', 'dlrs'): 0.007575757575757576,
#  ('mln', 'dlrs', 'it'): 0.007547169811320755,
#  ('dlrs', 'it', 'said'): 0.007575757575757576,
#  ('it', 'said', '</s>'): 0.007547169811320755,
#  ('said', '</s>', '<s>'): 0.007575757575757576,
#  ('<s>', '<s>', 'the'): 0.02456140350877193,
#  ('<s>', 'the', 'april'): 0.007434944237918215,
#  ('the', 'april', '6'): 0.007575757575757576,
#  ('april', '6', 'sale'): 0.007575757575757576,
#  ('6', 'sale', 'to'): 0.007575757575757576,
#  ('sale', 'to', 'be'): 0.007575757575757576,
#  ('to', 'be', 'evenly'): 0.007575757575757576,
#  ('be', 'evenly', 'divided'): 0.007575757575757576,
#  ('evenly', 'divided', 'between'): 0.007575757575757576,
#  ('divided', 'between', 'the'): 0.007575757575757576,
#  ('between', 'the', 'three'): 0.007575757575757576,
#  ('the', 'three', 'and'): 0.007575757575757576,
#  ('three', 'and', 'six'): 0.007575757575757576,
#  ('and', 'six', 'month'): 0.007575757575757576,
#  ('six', 'month', 'issues'): 0.007575757575757576,
#  ('month', 'issues', 'will'): 0.007575757575757576,
#  ('issues', 'will', 'result'): 0.007575757575757576,
#  ('will', 'result', 'in'): 0.007575757575757576,
#  ('result', 'in', 'a'): 0.007575757575757576,
#  ('in', 'a', 'paydown'): 0.007575757575757576,
#  ('a', 'paydown', 'of'): 0.007575757575757576,
#  ('paydown', 'of', '165'): 0.007575757575757576,
#  ('of', '165', 'billion'): 0.007575757575757576,
#  ('165', 'billion', 'dlrs'): 0.007575757575757576,
#  ('billion', 'dlrs', 'as'): 0.007547169811320755,
#  ('dlrs', 'as', 'maturing'): 0.007575757575757576,
#  ('as', 'maturing', 'bills'): 0.007575757575757576,
#  ('maturing', 'bills', 'total'): 0.007575757575757576,
#  ('bills', 'total', '1485'): 0.007575757575757576,
#  ('total', '1485', 'billion'): 0.007575757575757576,
#  ('1485', 'billion', 'dlrs'): 0.007575757575757576,
#  ('billion', 'dlrs', '</s>'): 0.007547169811320755,
#  ('dlrs', '</s>', '<s>'): 0.011320754716981131,
#  ('<s>', '<s>', 'waste'): 0.007017543859649123,
#  ('<s>', 'waste', 'managements'): 0.007575757575757576,
#  ('waste', 'managements', 'tender'): 0.007575757575757576,
#  ('managements', 'tender', 'offer'): 0.007575757575757576,
#  ('tender', 'offer', 'announced'): 0.007575757575757576,
#  ('offer', 'announced', 'before'): 0.007575757575757576,
#  ('announced', 'before', 'the'): 0.007575757575757576,
#  ('before', 'the', 'opening'): 0.007575757575757576,
#  ('the', 'opening', 'today'): 0.007575757575757576,
#  ('opening', 'today', 'expires'): 0.007575757575757576,
#  ('today', 'expires', 'march'): 0.007575757575757576,
#  ('expires', 'march', '25'): 0.007575757575757576,
#  ('march', '25', '</s>'): 0.007575757575757576,
#  ('25', '</s>', '<s>'): 0.007575757575757576,
#  ('<s>', '<s>', 'he'): 0.007017543859649123,
#  ('<s>', 'he', 'earlier'): 0.007575757575757576,
#  ('he', 'earlier', 'estimated'): 0.007575757575757576,
#  ('earlier', 'estimated', 'the'): 0.007575757575757576,
#  ('estimated', 'the', 'damage'): 0.007575757575757576,
#  ('the', 'damage', 'from'): 0.007575757575757576,
#  ('damage', 'from', 'the'): 0.007575757575757576,
#  ('from', 'the', 'us'): 0.007575757575757576,
#  ('the', 'us', 'raid'): 0.007547169811320755,
#  ('us', 'raid', 'at'): 0.007575757575757576,
#  ('raid', 'at', 'about'): 0.007575757575757576,
#  ('at', 'about', '500'): 0.007575757575757576,
#  ('about', '500', 'mln'): 0.007575757575757576,
#  ('500', 'mln', 'dlrs'): 0.007575757575757576,
#  ('mln', 'dlrs', '</s>'): 0.007547169811320755,
#  ('<s>', '<s>', 'brougher'): 0.007017543859649123,
#  ('<s>', 'brougher', 'bigi'): 0.007575757575757576,
#  ('brougher', 'bigi', 'to'): 0.007575757575757576,
#  ('bigi', 'to', 'sell'): 0.007575757575757576,
#  ('to', 'sell', '40'): 0.007575757575757576,
#  ('sell', '40', 'pct'): 0.007575757575757576,
#  ('40', 'pct', 'of'): 0.007575757575757576,
#  ('pct', 'of', 'subsidiary'): 0.007575757575757576,
#  ('of', 'subsidiary', '</s>'): 0.007575757575757576,
#  ('subsidiary', '</s>', '<s>'): 0.007575757575757576,
#  ('<s>', '<s>', 'that'): 0.007017543859649123,
#  ('<s>', 'that', 'was'): 0.007575757575757576,
#  ('that', 'was', 'not'): 0.007575757575757576,
#  ('was', 'not', 'the'): 0.007575757575757576,
#  ('not', 'the', 'case'): 0.007575757575757576,
#  ('the', 'case', 'two'): 0.007575757575757576,
#  ('case', 'two', 'years'): 0.007575757575757576,
#  ('two', 'years', 'ago'): 0.007575757575757576,
#  ('years', 'ago', '</s>'): 0.007575757575757576,
#  ('ago', '</s>', '<s>'): 0.007575757575757576,
#  ('<s>', '<s>', 'cutrale'): 0.007017543859649123,
#  ('<s>', 'cutrale', 'and'): 0.007575757575757576,
#  ('cutrale', 'and', 'citrosuco'): 0.007575757575757576,
#  ('and', 'citrosuco', 'officials'): 0.007575757575757576,
#  ('citrosuco', 'officials', 'were'): 0.007575757575757576,
#  ('officials', 'were', 'not'): 0.007575757575757576,
#  ('were', 'not', 'immediately'): 0.007575757575757576,
#  ('not', 'immediately', 'available'): 0.007575757575757576,
#  ('immediately', 'available', 'for'): 0.007575757575757576,
#  ('available', 'for', 'comment'): 0.007575757575757576,
#  ('for', 'comment', '</s>'): 0.007575757575757576,
#  ('comment', '</s>', '<s>'): 0.007575757575757576,
#  ('<s>', 'the', 'exchange'): 0.007434944237918215,
#  ('the', 'exchange', 'market'): 0.007575757575757576,
#  ('exchange', 'market', 'is'): 0.007575757575757576,
#  ('market', 'is', 'apparently'): 0.007575757575757576,
#  ('is', 'apparently', 'reacting'): 0.007575757575757576,
#  ('apparently', 'reacting', 'too'): 0.007575757575757576,
#  ('reacting', 'too', 'much'): 0.007575757575757576,
#  ('too', 'much', 'and'): 0.007575757575757576,
#  ('much', 'and', 'anyone'): 0.007575757575757576,
#  ('and', 'anyone', 'who'): 0.007575757575757576,
#  ('anyone', 'who', 'sold'): 0.007575757575757576,
#  ('who', 'sold', 'the'): 0.007575757575757576,
#  ('sold', 'the', 'dollar'): 0.007575757575757576,
#  ('the', 'dollar', 'on'): 0.007575757575757576,
#  ('dollar', 'on', 'the'): 0.007575757575757576,
#  ('on', 'the', 'baker'): 0.007547169811320755,
#  ('the', 'baker', 'comment'): 0.007575757575757576,
#  ('baker', 'comment', 'will'): 0.007575757575757576,
#  ('comment', 'will', 'regret'): 0.007575757575757576,
#  ('will', 'regret', 'it'): 0.007575757575757576,
#  ('regret', 'it', 'later'): 0.007575757575757576,
#  ('it', 'later', 'on'): 0.007575757575757576,
#  ('later', 'on', 'the'): 0.007575757575757576,
#  ('on', 'the', 'bank'): 0.007547169811320755,
#  ('the', 'bank', 'of'): 0.007575757575757576,
#  ('bank', 'of', 'japan'): 0.007575757575757576,
#  ('of', 'japan', 'official'): 0.007575757575757576,
#  ('japan', 'official', 'told'): 0.007575757575757576,
#  ('official', 'told', '</s>'): 0.007575757575757576,
#  ('told', '</s>', '<s>'): 0.007575757575757576,
#  ('<s>', '<s>', 'it'): 0.007017543859649123,
#  ('<s>', 'it', 'said'): 0.007575757575757576,
#  ('it', 'said', 'intensifying'): 0.007547169811320755,
#  ('said', 'intensifying', 'competition'): 0.007575757575757576,
#  ('intensifying', 'competition', 'in'): 0.007575757575757576,
#  ('competition', 'in', 'an'): 0.007575757575757576,
#  ('in', 'an', 'environment'): 0.007547169811320755,
#  ('an', 'environment', 'of'): 0.007575757575757576,
#  ('environment', 'of', 'slow'): 0.007575757575757576,
#  ('of', 'slow', 'economic'): 0.007575757575757576,
#  ('slow', 'economic', 'growth'): 0.007575757575757576,
#  ('economic', 'growth', 'moodys'): 0.007575757575757576,
#  ('growth', 'moodys', 'predicts'): 0.007575757575757576,
#  ('moodys', 'predicts', '25'): 0.007575757575757576,
#  ('predicts', '25', 'pct'): 0.007575757575757576,
#  ('25', 'pct', 'worldwide'): 0.007575757575757576,
#  ('pct', 'worldwide', 'growth'): 0.007575757575757576,
#  ('worldwide', 'growth', 'in'): 0.007575757575757576,
#  ('growth', 'in', '1987'): 0.007575757575757576,
#  ('in', '1987', 'will'): 0.007575757575757576,
#  ('1987', 'will', 'lower'): 0.007575757575757576,
#  ('will', 'lower', 'returns'): 0.007575757575757576,
#  ('lower', 'returns', 'and'): 0.007575757575757576,
#  ('returns', 'and', 'margins'): 0.007575757575757576,
#  ('and', 'margins', 'for'): 0.007575757575757576,
#  ('margins', 'for', 'many'): 0.007575757575757576,
#  ('for', 'many', 'multinational'): 0.007575757575757576,
#  ('many', 'multinational', 'firms'): 0.007575757575757576,
#  ('multinational', 'firms', '</s>'): 0.007575757575757576,
#  ('firms', '</s>', '<s>'): 0.007575757575757576,
#  ('<s>', 'the', 'payment'): 0.007434944237918215,
#  ('the', 'payment', 'date'): 0.007575757575757576,
#  ('payment', 'date', 'is'): 0.007575757575757576,
#  ('date', 'is', 'april'): 0.007575757575757576,
#  ('is', 'april', '8'): 0.007575757575757576,
#  ('april', '8', 'and'): 0.007575757575757576,
#  ('8', 'and', 'there'): 0.007575757575757576,
#  ('and', 'there', 'will'): 0.007575757575757576,
#  ('there', 'will', 'be'): 0.007575757575757576,
#  ('will', 'be', 'a'): 0.007518796992481203,
#  ('be', 'a', 'long'): 0.007575757575757576,
#  ('a', 'long', 'first'): 0.007575757575757576,
#  ('long', 'first', 'coupon'): 0.007575757575757576,
#  ('first', 'coupon', 'period'): 0.007575757575757576,
#  ('coupon', 'period', '</s>'): 0.007575757575757576,
#  ('period', '</s>', '<s>'): 0.007575757575757576,
#  ('<s>', '<s>', 'shr'): 0.007017543859649123,
#  ('<s>', 'shr', '57'): 0.007575757575757576,
#  ('shr', '57', 'cts'): 0.007575757575757576,
#  ('57', 'cts', 'vs'): 0.007575757575757576,
#  ('cts', 'vs', 'not'): 0.007575757575757576,
#  ('vs', 'not', 'given'): 0.011320754716981131,
#  ('not', 'given', 'net'): 0.011320754716981131,
#  ('given', 'net', '6889000'): 0.007547169811320755,
#  ('net', '6889000', 'vs'): 0.007575757575757576,
#  ('6889000', 'vs', '107'): 0.007575757575757576,
#  ('vs', '107', 'mln'): 0.007575757575757576,
#  ('107', 'mln', 'nine'): 0.007575757575757576,
#  ('mln', 'nine', 'mths'): 0.007575757575757576,
#  ('nine', 'mths', 'shr'): 0.007575757575757576,
#  ('mths', 'shr', '167'): 0.007575757575757576,
#  ('shr', '167', 'dlrs'): 0.007575757575757576,
#  ('167', 'dlrs', 'vs'): 0.007575757575757576,
#  ('dlrs', 'vs', 'not'): 0.007575757575757576,
#  ('given', 'net', '201'): 0.007547169811320755,
#  ('net', '201', 'mln'): 0.007575757575757576,
#  ('201', 'mln', 'vs'): 0.007575757575757576,
#  ('mln', 'vs', '230'): 0.007575757575757576,
#  ('vs', '230', 'mln'): 0.007575757575757576,
#  ('230', 'mln', 'note'): 0.007575757575757576,
#  ('mln', 'note', 'company'): 0.007575757575757576,
#  ('note', 'company', 'went'): 0.007575757575757576,
#  ('company', 'went', 'public'): 0.007575757575757576,
#  ('went', 'public', 'in'): 0.007575757575757576,
#  ('public', 'in', 'november'): 0.007575757575757576,
#  ('in', 'november', '1986'): 0.007575757575757576,
#  ('november', '1986', '</s>'): 0.007575757575757576,
#  ('1986', '</s>', '<s>'): 0.007575757575757576,
#  ('<s>', '<s>', 'baker'): 0.007017543859649123,
#  ('<s>', 'baker', 'had'): 0.007575757575757576,
#  ('baker', 'had', 'said'): 0.007575757575757576,
#  ('had', 'said', 'that'): 0.007575757575757576,
#  ('said', 'that', 'west'): 0.007575757575757576,
#  ('that', 'west', 'germany'): 0.007575757575757576,
#  ('west', 'germany', 'was'): 0.007575757575757576,
#  ('germany', 'was', 'apparently'): 0.007575757575757576,
#  ('was', 'apparently', 'breaching'): 0.007575757575757576,
#  ('apparently', 'breaching', 'the'): 0.007575757575757576,
#  ('breaching', 'the', 'louvre'): 0.007575757575757576,
#  ('the', 'louvre', 'accord'): 0.007575757575757576,
#  ('louvre', 'accord', '</s>'): 0.007575757575757576,
#  ('accord', '</s>', '<s>'): 0.007575757575757576,
#  ('<s>', '<s>', 'miniscribe'): 0.007017543859649123,
#  ('<s>', 'miniscribe', 'corp'): 0.007575757575757576,
#  ('miniscribe', 'corp', 'said'): 0.007575757575757576,
#  ('corp', 'said', 'it'): 0.011320754716981131,
#  ('said', 'it', 'filed'): 0.007547169811320755,
#  ('it', 'filed', 'with'): 0.007575757575757576,
#  ('filed', 'with', 'the'): 0.007575757575757576,
#  ('with', 'the', 'securities'): 0.007575757575757576,
#  ('the', 'securities', 'and'): 0.007575757575757576,
#  ('securities', 'and', 'exchange'): 0.007575757575757576,
#  ('and', 'exchange', 'commission'): 0.007575757575757576,
#  ('exchange', 'commission', 'a'): 0.007575757575757576,
#  ('commission', 'a', 'registration'): 0.007575757575757576,
#  ('a', 'registration', 'statement'): 0.007575757575757576,
#  ('registration', 'statement', 'covering'): 0.007575757575757576,
#  ('statement', 'covering', 'a'): 0.007575757575757576,
#  ('covering', 'a', '65'): 0.007575757575757576,
#  ('a', '65', 'mln'): 0.007575757575757576,
#  ('65', 'mln', 'dlr'): 0.007575757575757576,
#  ('mln', 'dlr', 'issue'): 0.007575757575757576,
#  ('dlr', 'issue', 'of'): 0.007575757575757576,
#  ('issue', 'of', 'convertible'): 0.007575757575757576,
#  ('of', 'convertible', 'subordinated'): 0.007575757575757576,
#  ('convertible', 'subordinated', 'debentures'): 0.007575757575757576,
#  ('subordinated', 'debentures', 'due'): 0.007575757575757576,
#  ('debentures', 'due', '2012'): 0.007575757575757576,
#  ('due', '2012', '</s>'): 0.007575757575757576,
#  ('2012', '</s>', '<s>'): 0.007575757575757576,
#  ('<s>', 'the', 'us'): 0.007434944237918215,
#  ('the', 'us', 'charges'): 0.007547169811320755,
#  ('us', 'charges', 'that'): 0.007575757575757576,
#  ('charges', 'that', 'the'): 0.007575757575757576,
#  ('that', 'the', 'europeans'): 0.007575757575757576,
#  ('the', 'europeans', 'are'): 0.007575757575757576,
#  ('europeans', 'are', 'violating'): 0.007575757575757576,
#  ('are', 'violating', 'rules'): 0.007575757575757576,
#  ('violating', 'rules', 'laid'): 0.007575757575757576,
#  ('rules', 'laid', 'down'): 0.007575757575757576,
#  ('laid', 'down', 'in'): 0.007575757575757576,
#  ('down', 'in', 'the'): 0.007575757575757576,
#  ('in', 'the', '1979'): 0.007547169811320755,
#  ('the', '1979', 'agreement'): 0.007575757575757576,
#  ('1979', 'agreement', 'on'): 0.007575757575757576,
#  ('agreement', 'on', 'trade'): 0.007575757575757576,
#  ('on', 'trade', 'in'): 0.007575757575757576,
#  ('trade', 'in', 'civil'): 0.007575757575757576,
#  ('in', 'civil', 'aircraft'): 0.007575757575757576,
#  ('civil', 'aircraft', '</s>'): 0.007575757575757576,
#  ('aircraft', '</s>', '<s>'): 0.007575757575757576,
#  ('<s>', 'the', 'company'): 0.011152416356877323,
#  ('the', 'company', 'did'): 0.007547169811320755,
#  ('company', 'did', 'not'): 0.007575757575757576,
#  ('did', 'not', 'name'): 0.007575757575757576,
#  ('not', 'name', 'an'): 0.007575757575757576,
#  ('name', 'an', 'underwriter'): 0.007575757575757576,
#  ('an', 'underwriter', 'for'): 0.007575757575757576,
#  ('underwriter', 'for', 'the'): 0.007575757575757576,
#  ('for', 'the', 'sale'): 0.007575757575757576,
#  ('the', 'sale', '</s>'): 0.007575757575757576,
#  ('sale', '</s>', '<s>'): 0.007575757575757576,
#  ('<s>', '<s>', 'phelps'): 0.007017543859649123,
#  ('<s>', 'phelps', 'dodge'): 0.007575757575757576,
#  ('phelps', 'dodge', 'corp'): 0.007575757575757576,
#  ('dodge', 'corp', 'said'): 0.007575757575757576,
#  ('said', 'it', 'is'): 0.007547169811320755,
#  ('it', 'is', 'calling'): 0.007575757575757576,
#  ('is', 'calling', 'for'): 0.007575757575757576,
#  ('calling', 'for', 'redemption'): 0.007575757575757576,
#  ('for', 'redemption', 'on'): 0.007575757575757576,
#  ('redemption', 'on', 'may'): 0.007575757575757576,
#  ('on', 'may', 'one'): 0.007575757575757576,
#  ('may', 'one', 'all'): 0.007575757575757576,
#  ('one', 'all', 'of'): 0.007575757575757576,
#  ('all', 'of', 'its'): 0.007575757575757576,
#  ('of', 'its', 'five'): 0.007575757575757576,
#  ('its', 'five', 'dlr'): 0.007575757575757576,
#  ('five', 'dlr', 'convertible'): 0.007575757575757576,
#  ('dlr', 'convertible', 'exchangeable'): 0.007575757575757576,
#  ('convertible', 'exchangeable', 'preference'): 0.007575757575757576,
#  ('exchangeable', 'preference', 'shares'): 0.007575757575757576,
#  ('preference', 'shares', 'at'): 0.007575757575757576,
#  ('shares', 'at', '5350'): 0.007575757575757576,
#  ('at', '5350', 'dlrs'): 0.007575757575757576,
#  ('5350', 'dlrs', 'per'): 0.007575757575757576,
#  ('dlrs', 'per', 'share'): 0.007575757575757576,
#  ('per', 'share', '</s>'): 0.007575757575757576,
#  ('share', '</s>', '<s>'): 0.007575757575757576,
#  ('<s>', '<s>', 'this'): 0.007017543859649123,
#  ('<s>', 'this', 'is'): 0.007575757575757576,
#  ('this', 'is', 'not'): 0.007575757575757576,
#  ('is', 'not', 'an'): 0.007575757575757576,
#  ('not', 'an', 'attempt'): 0.007575757575757576,
#  ('an', 'attempt', 'by'): 0.007575757575757576,
#  ('attempt', 'by', 'squibb'): 0.007575757575757576,
#  ('by', 'squibb', 'to'): 0.007575757575757576,
#  ('squibb', 'to', 'become'): 0.007575757575757576,
#  ('to', 'become', 'a'): 0.007575757575757576,
#  ('become', 'a', 'major'): 0.007575757575757576,
#  ('a', 'major', 'majority'): 0.007575757575757576,
#  ('major', 'majority', 'holder'): 0.007575757575757576,
#  ('majority', 'holder', 'in'): 0.007575757575757576,
#  ('holder', 'in', 'cetus'): 0.007575757575757576,
#  ('in', 'cetus', 'fildes'): 0.007575757575757576,
#  ('cetus', 'fildes', 'told'): 0.007575757575757576,
#  ('fildes', 'told', 'in'): 0.007575757575757576,
#  ('told', 'in', 'an'): 0.007575757575757576,
#  ('in', 'an', 'interview'): 0.007547169811320755,
#  ('an', 'interview', '</s>'): 0.007575757575757576,
#  ('interview', '</s>', '<s>'): 0.007575757575757576,
#  ('the', 'company', 'said'): 0.007547169811320755,
#  ('company', 'said', 'its'): 0.007575757575757576,
#  ('said', 'its', 'board'): 0.007575757575757576,
#  ('its', 'board', 'intendsd'): 0.007575757575757576,
#  ('board', 'intendsd', 'to'): 0.007575757575757576,
#  ('intendsd', 'to', 'schedule'): 0.007575757575757576,
#  ('to', 'schedule', 'a'): 0.007575757575757576,
#  ('schedule', 'a', 'meeting'): 0.007575757575757576,
#  ('a', 'meeting', 'in'): 0.007575757575757576,
#  ('meeting', 'in', 'the'): 0.007575757575757576,
#  ('in', 'the', 'near'): 0.007547169811320755,
#  ('the', 'near', 'future'): 0.007575757575757576,
#  ('near', 'future', 'to'): 0.007575757575757576,
#  ('future', 'to', 'review'): 0.007575757575757576,
#  ('to', 'review', 'the'): 0.007575757575757576,
#  ('review', 'the', 'proposal'): 0.007575757575757576,
#  ('the', 'proposal', 'and'): 0.007575757575757576,
#  ('proposal', 'and', 'it'): 0.007575757575757576,
#  ('and', 'it', 'has'): 0.007575757575757576,
#  ('it', 'has', 'asked'): 0.007575757575757576,
#  ('has', 'asked', 'oppenheimer'): 0.007575757575757576,
#  ('asked', 'oppenheimer', 'and'): 0.007575757575757576,
#  ('oppenheimer', 'and', 'co'): 0.007575757575757576,
#  ('and', 'co', 'inc'): 0.007575757575757576,
#  ('co', 'inc', 'to'): 0.007575757575757576,
#  ('inc', 'to', 'assist'): 0.007575757575757576,
#  ('to', 'assist', 'it'): 0.007575757575757576,
#  ('assist', 'it', 'in'): 0.007575757575757576,
#  ('it', 'in', 'evaluating'): 0.007575757575757576,
#  ('in', 'evaluating', 'the'): 0.007575757575757576,
#  ('evaluating', 'the', 'offer'): 0.007575757575757576,
#  ('the', 'offer', 'and'): 0.007575757575757576,
#  ('offer', 'and', 'advise'): 0.007575757575757576,
#  ('and', 'advise', 'calny'): 0.007575757575757576,
#  ('advise', 'calny', 'on'): 0.007575757575757576,
#  ('calny', 'on', 'its'): 0.007575757575757576,
#  ('on', 'its', 'alternatives'): 0.007575757575757576,
#  ('its', 'alternatives', '</s>'): 0.007575757575757576}
