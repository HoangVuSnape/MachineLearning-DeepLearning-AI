# %% [markdown]
# # Install

# %%
#author: Bui Anh Phu
#id: 521H0508
# !pip install python-sat==0.1.7.dev12
# Out:
# Collecting python-sat==0.1.7.dev12
#   Using cached python-sat-0.1.7.dev12.tar.gz (3.6 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: six in c:\users\tqbao\appdata\local\programs\python\python310\lib\site-packages (from python-sat==0.1.7.dev12) (1.16.0)
# Using legacy 'setup.py install' for python-sat, since package 'wheel' is not installed.
# Installing collected packages: python-sat
#   Attempting uninstall: python-sat
#     Found existing installation: python-sat 0.1.8.dev2
#     Uninstalling python-sat-0.1.8.dev2:
#       Successfully uninstalled python-sat-0.1.8.dev2
#   Running setup.py install for python-sat: started
#   Running setup.py install for python-sat: finished with status 'error'
#   Rolling back uninstall of python-sat
#   Moving to c:\users\tqbao\appdata\local\programs\python\python310\lib\site-packages\pycard.cp310-win_amd64.pyd
#    from C:\Users\tqbao\AppData\Local\Temp\pip-uninstall-d9rbuwvj\pycard.cp310-win_amd64.pyd
#   Moving to c:\users\tqbao\appdata\local\programs\python\python310\lib\site-packages\pysat\
#    from C:\Users\tqbao\AppData\Local\Programs\Python\Python310\Lib\site-packages\~ysat
#   Moving to c:\users\tqbao\appdata\local\programs\python\python310\lib\site-packages\pysolvers.cp310-win_amd64.pyd
#    from C:\Users\tqbao\AppData\Local\Temp\pip-uninstall-d9rbuwvj\pysolvers.cp310-win_amd64.pyd
#   Moving to c:\users\tqbao\appdata\local\programs\python\python310\lib\site-packages\python_sat-0.1.8.dev2.dist-info\
#    from C:\Users\tqbao\AppData\Local\Programs\Python\Python310\Lib\site-packages\~ython_sat-0.1.8.dev2.dist-info
#   Moving to c:\users\tqbao\appdata\local\programs\python\python310\scripts\__pycache__\
#    from C:\Users\tqbao\AppData\Local\Programs\Python\Python310\Scripts\~_pycache__
#   Moving to c:\users\tqbao\appdata\local\programs\python\python310\scripts\fm.py
#    from C:\Users\tqbao\AppData\Local\Temp\pip-uninstall-naxcan4o\fm.py
#   Moving to c:\users\tqbao\appdata\local\programs\python\python310\scripts\genhard.py
#    from C:\Users\tqbao\AppData\Local\Temp\pip-uninstall-naxcan4o\genhard.py
#   Moving to c:\users\tqbao\appdata\local\programs\python\python310\scripts\lbx.py
#    from C:\Users\tqbao\AppData\Local\Temp\pip-uninstall-naxcan4o\lbx.py
#   Moving to c:\users\tqbao\appdata\local\programs\python\python310\scripts\lsu.py
#    from C:\Users\tqbao\AppData\Local\Temp\pip-uninstall-naxcan4o\lsu.py
#   Moving to c:\users\tqbao\appdata\local\programs\python\python310\scripts\mcsls.py
#    from C:\Users\tqbao\AppData\Local\Temp\pip-uninstall-naxcan4o\mcsls.py
#   Moving to c:\users\tqbao\appdata\local\programs\python\python310\scripts\models.py
#    from C:\Users\tqbao\AppData\Local\Temp\pip-uninstall-naxcan4o\models.py
#   Moving to c:\users\tqbao\appdata\local\programs\python\python310\scripts\musx.py
#    from C:\Users\tqbao\AppData\Local\Temp\pip-uninstall-naxcan4o\musx.py
#   Moving to c:\users\tqbao\appdata\local\programs\python\python310\scripts\optux.py
#    from C:\Users\tqbao\AppData\Local\Temp\pip-uninstall-naxcan4o\optux.py
#   Moving to c:\users\tqbao\appdata\local\programs\python\python310\scripts\rc2.py
#    from C:\Users\tqbao\AppData\Local\Temp\pip-uninstall-naxcan4o\rc2.py
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for python-sat did not run successfully.
#   │ exit code: 1
#   ╰─> [2143 lines of output]
#       preparing cadical
#       not downloading solvers/cadical.tar.gz since it exists locally
#       extracting solvers/cadical.tar.gz
#       False cadical-rel-1.0.3 cadical
#       adapting cadical's files
#       patching cadical
#
#
#
#       Copyright (c) Microsoft Corporation. All rights reserved.
#
#
#
#
#
#       Usage: wsl.exe [Argument]
#
#
#
#
#
#       Arguments:
#
#
#
#
#
#           --install <Options>
#
#
#               Install Windows Subsystem for Linux features. If no options are specified,
#
#
#               the recommended features will be installed along with the default distribution.
#
#
#
#
#
#               To view the default distribution as well as a list of other valid distributions,
#
#
#               use 'wsl --list --online'.
#
#
#
#
#
#               Options:
#
#
#                   --distribution, -d [Argument]
#
#
#                       Specifies the distribution to be downloaded and installed by name.
#
#
#
#
#
#                       Arguments:
#
#
#                           A valid distribution name (not case sensitive).
#
#
#
#
#
#                       Examples:
#
#
#                           wsl --install -d Ubuntu
#
#
#                           wsl --install --distribution Debian
#
#
#
#
#
#                   --inbox
#
#
#                       Install the optional Windows feature instead of the version available via the Microsoft Store.
#
#
#
#
#
#                   --enable-wsl1
#
#
#                       Enable WSL1 support with the Microsoft Store version.
#
#
#
#
#
#                   --no-distribution
#
#
#                       Do not install a distribution (cannot be used with --distribution).
#
#
#
#
#
#                   --no-launch, -n
#
#
#                       Do not launch the distribution after install.
#
#
#
#
#
#                   --web-download
#
#
#                       Download the most recent version of WSL from the internet instead of the Microsoft Store.
#
#
#
#
#
#           --list, -l [Options]
#
#
#               Lists distributions.
#
#
#
#
#
#               Options:
#
#
#                   --online, -o
#
#
#                       Displays a list of available distributions for install with 'wsl --install'.
#
#
#
#
#
#           --status
#
#
#               Show the status of Windows Subsystem for Linux.
#
#
#
#
#
#           --help
#
#
#               Display usage information.
#
#
#       preparing gluecard30
#       not downloading solvers/glucose30.tar.gz since it exists locally
#       extracting solvers/glucose30.tar.gz
#       False glucose-3.0 gluecard30
#       adapting gluecard30's files
#       patching gluecard30
#
#
#
#       Copyright (c) Microsoft Corporation. All rights reserved.
#
#
#
#
#
#       Usage: wsl.exe [Argument]
#
#
#
#
#
#       Arguments:
#
#
#
#
#
#           --install <Options>
#
#
#               Install Windows Subsystem for Linux features. If no options are specified,
#
#
#               the recommended features will be installed along with the default distribution.
#
#
#
#
#
#               To view the default distribution as well as a list of other valid distributions,
#
#
#               use 'wsl --list --online'.
#
#
#
#
#
#               Options:
#
#
#                   --distribution, -d [Argument]
#
#
#                       Specifies the distribution to be downloaded and installed by name.
#
#
#
#
#
#                       Arguments:
#
#
#                           A valid distribution name (not case sensitive).
#
#
#
#
#
#                       Examples:
#
#
#                           wsl --install -d Ubuntu
#
#
#                           wsl --install --distribution Debian
#
#
#
#
#
#                   --inbox
#
#
#                       Install the optional Windows feature instead of the version available via the Microsoft Store.
#
#
#
#
#
#                   --enable-wsl1
#
#
#                       Enable WSL1 support with the Microsoft Store version.
#
#
#
#
#
#                   --no-distribution
#
#
#                       Do not install a distribution (cannot be used with --distribution).
#
#
#
#
#
#                   --no-launch, -n
#
#
#                       Do not launch the distribution after install.
#
#
#
#
#
#                   --web-download
#
#
#                       Download the most recent version of WSL from the internet instead of the Microsoft Store.
#
#
#
#
#
#           --list, -l [Options]
#
#
#               Lists distributions.
#
#
#
#
#
#               Options:
#
#
#                   --online, -o
#
#
#                       Displays a list of available distributions for install with 'wsl --install'.
#
#
#
#
#
#           --status
#
#
#               Show the status of Windows Subsystem for Linux.
#
#
#
#
#
#           --help
#
#
#               Display usage information.
#
#
#       preparing gluecard41
#       not downloading solvers/glucose41.tar.gz since it exists locally
#       extracting solvers/glucose41.tar.gz
#       False glucose-syrup-4.1 gluecard41
#       adapting gluecard41's files
#       patching gluecard41
#
#
#
#       Copyright (c) Microsoft Corporation. All rights reserved.
#
#
#
#
#
#       Usage: wsl.exe [Argument]
#
#
#
#
#
#       Arguments:
#
#
#
#
#
#           --install <Options>
#
#
#               Install Windows Subsystem for Linux features. If no options are specified,
#
#
#               the recommended features will be installed along with the default distribution.
#
#
#
#
#
#               To view the default distribution as well as a list of other valid distributions,
#
#
#               use 'wsl --list --online'.
#
#
#
#
#
#               Options:
#
#
#                   --distribution, -d [Argument]
#
#
#                       Specifies the distribution to be downloaded and installed by name.
#
#
#
#
#
#                       Arguments:
#
#
#                           A valid distribution name (not case sensitive).
#
#
#
#
#
#                       Examples:
#
#
#                           wsl --install -d Ubuntu
#
#
#                           wsl --install --distribution Debian
#
#
#
#
#
#                   --inbox
#
#
#                       Install the optional Windows feature instead of the version available via the Microsoft Store.
#
#
#
#
#
#                   --enable-wsl1
#
#
#                       Enable WSL1 support with the Microsoft Store version.
#
#
#
#
#
#                   --no-distribution
#
#
#                       Do not install a distribution (cannot be used with --distribution).
#
#
#
#
#
#                   --no-launch, -n
#
#
#                       Do not launch the distribution after install.
#
#
#
#
#
#                   --web-download
#
#
#                       Download the most recent version of WSL from the internet instead of the Microsoft Store.
#
#
#
#
#
#           --list, -l [Options]
#
#
#               Lists distributions.
#
#
#
#
#
#               Options:
#
#
#                   --online, -o
#
#
#                       Displays a list of available distributions for install with 'wsl --install'.
#
#
#
#
#
#           --status
#
#
#               Show the status of Windows Subsystem for Linux.
#
#
#
#
#
#           --help
#
#
#               Display usage information.
#
#
#       preparing glucose30
#       not downloading solvers/glucose30.tar.gz since it exists locally
#       extracting solvers/glucose30.tar.gz
#       False glucose-3.0 glucose30
#       adapting glucose30's files
#       patching glucose30
#
#
#
#       Copyright (c) Microsoft Corporation. All rights reserved.
#
#
#
#
#
#       Usage: wsl.exe [Argument]
#
#
#
#
#
#       Arguments:
#
#
#
#
#
#           --install <Options>
#
#
#               Install Windows Subsystem for Linux features. If no options are specified,
#
#
#               the recommended features will be installed along with the default distribution.
#
#
#
#
#
#               To view the default distribution as well as a list of other valid distributions,
#
#
#               use 'wsl --list --online'.
#
#
#
#
#
#               Options:
#
#
#                   --distribution, -d [Argument]
#
#
#                       Specifies the distribution to be downloaded and installed by name.
#
#
#
#
#
#                       Arguments:
#
#
#                           A valid distribution name (not case sensitive).
#
#
#
#
#
#                       Examples:
#
#
#                           wsl --install -d Ubuntu
#
#
#                           wsl --install --distribution Debian
#
#
#
#
#
#                   --inbox
#
#
#                       Install the optional Windows feature instead of the version available via the Microsoft Store.
#
#
#
#
#
#                   --enable-wsl1
#
#
#                       Enable WSL1 support with the Microsoft Store version.
#
#
#
#
#
#                   --no-distribution
#
#
#                       Do not install a distribution (cannot be used with --distribution).
#
#
#
#
#
#                   --no-launch, -n
#
#
#                       Do not launch the distribution after install.
#
#
#
#
#
#                   --web-download
#
#
#                       Download the most recent version of WSL from the internet instead of the Microsoft Store.
#
#
#
#
#
#           --list, -l [Options]
#
#
#               Lists distributions.
#
#
#
#
#
#               Options:
#
#
#                   --online, -o
#
#
#                       Displays a list of available distributions for install with 'wsl --install'.
#
#
#
#
#
#           --status
#
#
#               Show the status of Windows Subsystem for Linux.
#
#
#
#
#
#           --help
#
#
#               Display usage information.
#
#
#       preparing glucose41
#       not downloading solvers/glucose41.tar.gz since it exists locally
#       extracting solvers/glucose41.tar.gz
#       False glucose-syrup-4.1 glucose41
#       adapting glucose41's files
#       patching glucose41
#
#
#
#       Copyright (c) Microsoft Corporation. All rights reserved.
#
#
#
#
#
#       Usage: wsl.exe [Argument]
#
#
#
#
#
#       Arguments:
#
#
#
#
#
#           --install <Options>
#
#
#               Install Windows Subsystem for Linux features. If no options are specified,
#
#
#               the recommended features will be installed along with the default distribution.
#
#
#
#
#
#               To view the default distribution as well as a list of other valid distributions,
#
#
#               use 'wsl --list --online'.
#
#
#
#
#
#               Options:
#
#
#                   --distribution, -d [Argument]
#
#
#                       Specifies the distribution to be downloaded and installed by name.
#
#
#
#
#
#                       Arguments:
#
#
#                           A valid distribution name (not case sensitive).
#
#
#
#
#
#                       Examples:
#
#
#                           wsl --install -d Ubuntu
#
#
#                           wsl --install --distribution Debian
#
#
#
#
#
#                   --inbox
#
#
#                       Install the optional Windows feature instead of the version available via the Microsoft Store.
#
#
#
#
#
#                   --enable-wsl1
#
#
#                       Enable WSL1 support with the Microsoft Store version.
#
#
#
#
#
#                   --no-distribution
#
#
#                       Do not install a distribution (cannot be used with --distribution).
#
#
#
#
#
#                   --no-launch, -n
#
#
#                       Do not launch the distribution after install.
#
#
#
#
#
#                   --web-download
#
#
#                       Download the most recent version of WSL from the internet instead of the Microsoft Store.
#
#
#
#
#
#           --list, -l [Options]
#
#
#               Lists distributions.
#
#
#
#
#
#               Options:
#
#
#                   --online, -o
#
#
#                       Displays a list of available distributions for install with 'wsl --install'.
#
#
#
#
#
#           --status
#
#
#               Show the status of Windows Subsystem for Linux.
#
#
#
#
#
#           --help
#
#
#               Display usage information.
#
#
#       preparing lingeling
#       not downloading solvers/lingeling.tar.gz since it exists locally
#       extracting solvers/lingeling.tar.gz
#       False lingeling-bbc-9230380-160707-druplig-009 lingeling
#       adapting lingeling's files
#       extracting solvers\lingeling\druplig-009.zip
#       True druplig-009 lingeling
#       extracting solvers\lingeling\lingeling-bbc-9230380-160707.tar.gz
#       True lingeling-bbc-9230380-160707 lingeling
#       patching lingeling
#
#
#
#       Copyright (c) Microsoft Corporation. All rights reserved.
#
#
#
#
#
#       Usage: wsl.exe [Argument]
#
#
#
#
#
#       Arguments:
#
#
#
#
#
#           --install <Options>
#
#
#               Install Windows Subsystem for Linux features. If no options are specified,
#
#
#               the recommended features will be installed along with the default distribution.
#
#
#
#
#
#               To view the default distribution as well as a list of other valid distributions,
#
#
#               use 'wsl --list --online'.
#
#
#
#
#
#               Options:
#
#
#                   --distribution, -d [Argument]
#
#
#                       Specifies the distribution to be downloaded and installed by name.
#
#
#
#
#
#                       Arguments:
#
#
#                           A valid distribution name (not case sensitive).
#
#
#
#
#
#                       Examples:
#
#
#                           wsl --install -d Ubuntu
#
#
#                           wsl --install --distribution Debian
#
#
#
#
#
#                   --inbox
#
#
#                       Install the optional Windows feature instead of the version available via the Microsoft Store.
#
#
#
#
#
#                   --enable-wsl1
#
#
#                       Enable WSL1 support with the Microsoft Store version.
#
#
#
#
#
#                   --no-distribution
#
#
#                       Do not install a distribution (cannot be used with --distribution).
#
#
#
#
#
#                   --no-launch, -n
#
#
#                       Do not launch the distribution after install.
#
#
#
#
#
#                   --web-download
#
#
#                       Download the most recent version of WSL from the internet instead of the Microsoft Store.
#
#
#
#
#
#           --list, -l [Options]
#
#
#               Lists distributions.
#
#
#
#
#
#               Options:
#
#
#                   --online, -o
#
#
#                       Displays a list of available distributions for install with 'wsl --install'.
#
#
#
#
#
#           --status
#
#
#               Show the status of Windows Subsystem for Linux.
#
#
#
#
#
#           --help
#
#
#               Display usage information.
#
#
#       preparing maplechrono
#       not downloading solvers/maplechrono.zip since it exists locally
#       extracting solvers/maplechrono.zip
#       False MapleLCMDistChronoBT maplechrono
#       adapting maplechrono's files
#       patching maplechrono
#
#
#
#       Copyright (c) Microsoft Corporation. All rights reserved.
#
#
#
#
#
#       Usage: wsl.exe [Argument]
#
#
#
#
#
#       Arguments:
#
#
#
#
#
#           --install <Options>
#
#
#               Install Windows Subsystem for Linux features. If no options are specified,
#
#
#               the recommended features will be installed along with the default distribution.
#
#
#
#
#
#               To view the default distribution as well as a list of other valid distributions,
#
#
#               use 'wsl --list --online'.
#
#
#
#
#
#               Options:
#
#
#                   --distribution, -d [Argument]
#
#
#                       Specifies the distribution to be downloaded and installed by name.
#
#
#
#
#
#                       Arguments:
#
#
#                           A valid distribution name (not case sensitive).
#
#
#
#
#
#                       Examples:
#
#
#                           wsl --install -d Ubuntu
#
#
#                           wsl --install --distribution Debian
#
#
#
#
#
#                   --inbox
#
#
#                       Install the optional Windows feature instead of the version available via the Microsoft Store.
#
#
#
#
#
#                   --enable-wsl1
#
#
#                       Enable WSL1 support with the Microsoft Store version.
#
#
#
#
#
#                   --no-distribution
#
#
#                       Do not install a distribution (cannot be used with --distribution).
#
#
#
#
#
#                   --no-launch, -n
#
#
#                       Do not launch the distribution after install.
#
#
#
#
#
#                   --web-download
#
#
#                       Download the most recent version of WSL from the internet instead of the Microsoft Store.
#
#
#
#
#
#           --list, -l [Options]
#
#
#               Lists distributions.
#
#
#
#
#
#               Options:
#
#
#                   --online, -o
#
#
#                       Displays a list of available distributions for install with 'wsl --install'.
#
#
#
#
#
#           --status
#
#
#               Show the status of Windows Subsystem for Linux.
#
#
#
#
#
#           --help
#
#
#               Display usage information.
#
#
#       preparing maplecm
#       not downloading solvers/maplecm.zip since it exists locally
#       extracting solvers/maplecm.zip
#       False Maple_CM maplecm
#       adapting maplecm's files
#       patching maplecm
#
#
#
#       Copyright (c) Microsoft Corporation. All rights reserved.
#
#
#
#
#
#       Usage: wsl.exe [Argument]
#
#
#
#
#
#       Arguments:
#
#
#
#
#
#           --install <Options>
#
#
#               Install Windows Subsystem for Linux features. If no options are specified,
#
#
#               the recommended features will be installed along with the default distribution.
#
#
#
#
#
#               To view the default distribution as well as a list of other valid distributions,
#
#
#               use 'wsl --list --online'.
#
#
#
#
#
#               Options:
#
#
#                   --distribution, -d [Argument]
#
#
#                       Specifies the distribution to be downloaded and installed by name.
#
#
#
#
#
#                       Arguments:
#
#
#                           A valid distribution name (not case sensitive).
#
#
#
#
#
#                       Examples:
#
#
#                           wsl --install -d Ubuntu
#
#
#                           wsl --install --distribution Debian
#
#
#
#
#
#                   --inbox
#
#
#                       Install the optional Windows feature instead of the version available via the Microsoft Store.
#
#
#
#
#
#                   --enable-wsl1
#
#
#                       Enable WSL1 support with the Microsoft Store version.
#
#
#
#
#
#                   --no-distribution
#
#
#                       Do not install a distribution (cannot be used with --distribution).
#
#
#
#
#
#                   --no-launch, -n
#
#
#                       Do not launch the distribution after install.
#
#
#
#
#
#                   --web-download
#
#
#                       Download the most recent version of WSL from the internet instead of the Microsoft Store.
#
#
#
#
#
#           --list, -l [Options]
#
#
#               Lists distributions.
#
#
#
#
#
#               Options:
#
#
#                   --online, -o
#
#
#                       Displays a list of available distributions for install with 'wsl --install'.
#
#
#
#
#
#           --status
#
#
#               Show the status of Windows Subsystem for Linux.
#
#
#
#
#
#           --help
#
#
#               Display usage information.
#
#
#       preparing maplesat
#       not downloading solvers/maplesat.zip since it exists locally
#       extracting solvers/maplesat.zip
#       False MapleCOMSPS_pure_LRB maplesat
#       adapting maplesat's files
#       patching maplesat
#
#
#
#       Copyright (c) Microsoft Corporation. All rights reserved.
#
#
#
#
#
#       Usage: wsl.exe [Argument]
#
#
#
#
#
#       Arguments:
#
#
#
#
#
#           --install <Options>
#
#
#               Install Windows Subsystem for Linux features. If no options are specified,
#
#
#               the recommended features will be installed along with the default distribution.
#
#
#
#
#
#               To view the default distribution as well as a list of other valid distributions,
#
#
#               use 'wsl --list --online'.
#
#
#
#
#
#               Options:
#
#
#                   --distribution, -d [Argument]
#
#
#                       Specifies the distribution to be downloaded and installed by name.
#
#
#
#
#
#                       Arguments:
#
#
#                           A valid distribution name (not case sensitive).
#
#
#
#
#
#                       Examples:
#
#
#                           wsl --install -d Ubuntu
#
#
#                           wsl --install --distribution Debian
#
#
#
#
#
#                   --inbox
#
#
#                       Install the optional Windows feature instead of the version available via the Microsoft Store.
#
#
#
#
#
#                   --enable-wsl1
#
#
#                       Enable WSL1 support with the Microsoft Store version.
#
#
#
#
#
#                   --no-distribution
#
#
#                       Do not install a distribution (cannot be used with --distribution).
#
#
#
#
#
#                   --no-launch, -n
#
#
#                       Do not launch the distribution after install.
#
#
#
#
#
#                   --web-download
#
#
#                       Download the most recent version of WSL from the internet instead of the Microsoft Store.
#
#
#
#
#
#           --list, -l [Options]
#
#
#               Lists distributions.
#
#
#
#
#
#               Options:
#
#
#                   --online, -o
#
#
#                       Displays a list of available distributions for install with 'wsl --install'.
#
#
#
#
#
#           --status
#
#
#               Show the status of Windows Subsystem for Linux.
#
#
#
#
#
#           --help
#
#
#               Display usage information.
#
#
#       preparing mergesat3
#       not downloading solvers/mergesat3.tar.gz since it exists locally
#       extracting solvers/mergesat3.tar.gz
#       False mergesat-3.0 mergesat3
#       adapting mergesat3's files
#       patching mergesat3
#
#
#
#       Copyright (c) Microsoft Corporation. All rights reserved.
#
#
#
#
#
#       Usage: wsl.exe [Argument]
#
#
#
#
#
#       Arguments:
#
#
#
#
#
#           --install <Options>
#
#
#               Install Windows Subsystem for Linux features. If no options are specified,
#
#
#               the recommended features will be installed along with the default distribution.
#
#
#
#
#
#               To view the default distribution as well as a list of other valid distributions,
#
#
#               use 'wsl --list --online'.
#
#
#
#
#
#               Options:
#
#
#                   --distribution, -d [Argument]
#
#
#                       Specifies the distribution to be downloaded and installed by name.
#
#
#
#
#
#                       Arguments:
#
#
#                           A valid distribution name (not case sensitive).
#
#
#
#
#
#                       Examples:
#
#
#                           wsl --install -d Ubuntu
#
#
#                           wsl --install --distribution Debian
#
#
#
#
#
#                   --inbox
#
#
#                       Install the optional Windows feature instead of the version available via the Microsoft Store.
#
#
#
#
#
#                   --enable-wsl1
#
#
#                       Enable WSL1 support with the Microsoft Store version.
#
#
#
#
#
#                   --no-distribution
#
#
#                       Do not install a distribution (cannot be used with --distribution).
#
#
#
#
#
#                   --no-launch, -n
#
#
#                       Do not launch the distribution after install.
#
#
#
#
#
#                   --web-download
#
#
#                       Download the most recent version of WSL from the internet instead of the Microsoft Store.
#
#
#
#
#
#           --list, -l [Options]
#
#
#               Lists distributions.
#
#
#
#
#
#               Options:
#
#
#                   --online, -o
#
#
#                       Displays a list of available distributions for install with 'wsl --install'.
#
#
#
#
#
#           --status
#
#
#               Show the status of Windows Subsystem for Linux.
#
#
#
#
#
#           --help
#
#
#               Display usage information.
#
#
#       preparing minicard
#       not downloading solvers/minicard.tar.gz since it exists locally
#       extracting solvers/minicard.tar.gz
#       False minicard-1.2 minicard
#       adapting minicard's files
#       patching minicard
#
#
#
#       Copyright (c) Microsoft Corporation. All rights reserved.
#
#
#
#
#
#       Usage: wsl.exe [Argument]
#
#
#
#
#
#       Arguments:
#
#
#
#
#
#           --install <Options>
#
#
#               Install Windows Subsystem for Linux features. If no options are specified,
#
#
#               the recommended features will be installed along with the default distribution.
#
#
#
#
#
#               To view the default distribution as well as a list of other valid distributions,
#
#
#               use 'wsl --list --online'.
#
#
#
#
#
#               Options:
#
#
#                   --distribution, -d [Argument]
#
#
#                       Specifies the distribution to be downloaded and installed by name.
#
#
#
#
#
#                       Arguments:
#
#
#                           A valid distribution name (not case sensitive).
#
#
#
#
#
#                       Examples:
#
#
#                           wsl --install -d Ubuntu
#
#
#                           wsl --install --distribution Debian
#
#
#
#
#
#                   --inbox
#
#
#                       Install the optional Windows feature instead of the version available via the Microsoft Store.
#
#
#
#
#
#                   --enable-wsl1
#
#
#                       Enable WSL1 support with the Microsoft Store version.
#
#
#
#
#
#                   --no-distribution
#
#
#                       Do not install a distribution (cannot be used with --distribution).
#
#
#
#
#
#                   --no-launch, -n
#
#
#                       Do not launch the distribution after install.
#
#
#
#
#
#                   --web-download
#
#
#                       Download the most recent version of WSL from the internet instead of the Microsoft Store.
#
#
#
#
#
#           --list, -l [Options]
#
#
#               Lists distributions.
#
#
#
#
#
#               Options:
#
#
#                   --online, -o
#
#
#                       Displays a list of available distributions for install with 'wsl --install'.
#
#
#
#
#
#           --status
#
#
#               Show the status of Windows Subsystem for Linux.
#
#
#
#
#
#           --help
#
#
#               Display usage information.
#
#
#       preparing minisat22
#       not downloading solvers/minisat22.tar.gz since it exists locally
#       extracting solvers/minisat22.tar.gz
#       False minisat minisat22
#       adapting minisat22's files
#       patching minisat22
#
#
#
#       Copyright (c) Microsoft Corporation. All rights reserved.
#
#
#
#
#
#       Usage: wsl.exe [Argument]
#
#
#
#
#
#       Arguments:
#
#
#
#
#
#           --install <Options>
#
#
#               Install Windows Subsystem for Linux features. If no options are specified,
#
#
#               the recommended features will be installed along with the default distribution.
#
#
#
#
#
#               To view the default distribution as well as a list of other valid distributions,
#
#
#               use 'wsl --list --online'.
#
#
#
#
#
#               Options:
#
#
#                   --distribution, -d [Argument]
#
#
#                       Specifies the distribution to be downloaded and installed by name.
#
#
#
#
#
#                       Arguments:
#
#
#                           A valid distribution name (not case sensitive).
#
#
#
#
#
#                       Examples:
#
#
#                           wsl --install -d Ubuntu
#
#
#                           wsl --install --distribution Debian
#
#
#
#
#
#                   --inbox
#
#
#                       Install the optional Windows feature instead of the version available via the Microsoft Store.
#
#
#
#
#
#                   --enable-wsl1
#
#
#                       Enable WSL1 support with the Microsoft Store version.
#
#
#
#
#
#                   --no-distribution
#
#
#                       Do not install a distribution (cannot be used with --distribution).
#
#
#
#
#
#                   --no-launch, -n
#
#
#                       Do not launch the distribution after install.
#
#
#
#
#
#                   --web-download
#
#
#                       Download the most recent version of WSL from the internet instead of the Microsoft Store.
#
#
#
#
#
#           --list, -l [Options]
#
#
#               Lists distributions.
#
#
#
#
#
#               Options:
#
#
#                   --online, -o
#
#
#                       Displays a list of available distributions for install with 'wsl --install'.
#
#
#
#
#
#           --status
#
#
#               Show the status of Windows Subsystem for Linux.
#
#
#
#
#
#           --help
#
#
#               Display usage information.
#
#
#       preparing minisatgh
#       not downloading solvers/minisatgh.zip since it exists locally
#       extracting solvers/minisatgh.zip
#       False minisat-master minisatgh
#       adapting minisatgh's files
#       patching minisatgh
#
#
#
#       Copyright (c) Microsoft Corporation. All rights reserved.
#
#
#
#
#
#       Usage: wsl.exe [Argument]
#
#
#
#
#
#       Arguments:
#
#
#
#
#
#           --install <Options>
#
#
#               Install Windows Subsystem for Linux features. If no options are specified,
#
#
#               the recommended features will be installed along with the default distribution.
#
#
#
#
#
#               To view the default distribution as well as a list of other valid distributions,
#
#
#               use 'wsl --list --online'.
#
#
#
#
#
#               Options:
#
#
#                   --distribution, -d [Argument]
#
#
#                       Specifies the distribution to be downloaded and installed by name.
#
#
#
#
#
#                       Arguments:
#
#
#                           A valid distribution name (not case sensitive).
#
#
#
#
#
#                       Examples:
#
#
#                           wsl --install -d Ubuntu
#
#
#                           wsl --install --distribution Debian
#
#
#
#
#
#                   --inbox
#
#
#                       Install the optional Windows feature instead of the version available via the Microsoft Store.
#
#
#
#
#
#                   --enable-wsl1
#
#
#                       Enable WSL1 support with the Microsoft Store version.
#
#
#
#
#
#                   --no-distribution
#
#
#                       Do not install a distribution (cannot be used with --distribution).
#
#
#
#
#
#                   --no-launch, -n
#
#
#                       Do not launch the distribution after install.
#
#
#
#
#
#                   --web-download
#
#
#                       Download the most recent version of WSL from the internet instead of the Microsoft Store.
#
#
#
#
#
#           --list, -l [Options]
#
#
#               Lists distributions.
#
#
#
#
#
#               Options:
#
#
#                   --online, -o
#
#
#                       Displays a list of available distributions for install with 'wsl --install'.
#
#
#
#
#
#           --status
#
#
#               Show the status of Windows Subsystem for Linux.
#
#
#
#
#
#           --help
#
#
#               Display usage information.
#
#
#       C:\Users\tqbao\AppData\Local\Programs\Python\Python310\lib\site-packages\setuptools\dist.py:717: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#         warnings.warn(
#       C:\Users\tqbao\AppData\Local\Programs\Python\Python310\lib\site-packages\setuptools\dist.py:717: UserWarning: Usage of dash-separated 'license-file' will not be supported in future versions. Please use the underscore name 'license_file' instead
#         warnings.warn(
#       running install
#       running build
#       running build_py
#       creating build
#       creating build\lib.win-amd64-3.10
#       creating build\lib.win-amd64-3.10\pysat
#       copying pysat\card.py -> build\lib.win-amd64-3.10\pysat
#       copying pysat\formula.py -> build\lib.win-amd64-3.10\pysat
#       copying pysat\pb.py -> build\lib.win-amd64-3.10\pysat
#       copying pysat\solvers.py -> build\lib.win-amd64-3.10\pysat
#       copying pysat\_fileio.py -> build\lib.win-amd64-3.10\pysat
#       copying pysat\_utils.py -> build\lib.win-amd64-3.10\pysat
#       copying pysat\__init__.py -> build\lib.win-amd64-3.10\pysat
#       creating build\lib.win-amd64-3.10\pysat\examples
#       copying examples\fm.py -> build\lib.win-amd64-3.10\pysat\examples
#       copying examples\genhard.py -> build\lib.win-amd64-3.10\pysat\examples
#       copying examples\hitman.py -> build\lib.win-amd64-3.10\pysat\examples
#       copying examples\lbx.py -> build\lib.win-amd64-3.10\pysat\examples
#       copying examples\lsu.py -> build\lib.win-amd64-3.10\pysat\examples
#       copying examples\mcsls.py -> build\lib.win-amd64-3.10\pysat\examples
#       copying examples\models.py -> build\lib.win-amd64-3.10\pysat\examples
#       copying examples\musx.py -> build\lib.win-amd64-3.10\pysat\examples
#       copying examples\optux.py -> build\lib.win-amd64-3.10\pysat\examples
#       copying examples\rc2.py -> build\lib.win-amd64-3.10\pysat\examples
#       copying examples\usage.py -> build\lib.win-amd64-3.10\pysat\examples
#       copying examples\__init__.py -> build\lib.win-amd64-3.10\pysat\examples
#       running build_ext
#       building 'pycard' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   WARNING: No metadata found in c:\users\tqbao\appdata\local\programs\python\python310\lib\site-packages
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> python-sat
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
# WARNING: You are using pip version 22.0.4; however, version 23.1.1 is available.
# You should consider upgrading via the 'C:\Users\tqbao\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# # Libraries

# %%
from pysat.solvers import Glucose3
from pysat.formula import CNF
import random

# %% [markdown]
# # Classes

# %%
class NQueenSolver:
    def __init__(self, n):
        self.solver = Glucose3()
        self.n = n
        self.vars = [[i*self.n + j + 1 for j in range(self.n)] for i in range(self.n)]
        self.clauses = CNF()
        self.add_row_constraints()
        self.add_col_constraints()
        self.add_diagonal_constraints()

    def add_row_constraints(self):
        for i in range(self.n):
            clause = [self.vars[i][j] for j in range(self.n)]
            self.clauses.append(clause)
            for j1 in range(self.n):
                for j2 in range(j1+1, self.n):
                    clause = [-self.vars[i][j1], -self.vars[i][j2]]
                    self.clauses.append(clause)

    def add_col_constraints(self):
        for j in range(self.n):
            clause = [self.vars[i][j] for i in range(self.n)]
            self.clauses.append(clause)
            for i1 in range(self.n):
                for i2 in range(i1+1, self.n):
                    clause = [-self.vars[i1][j], -self.vars[i2][j]]
                    self.clauses.append(clause)

    def add_diagonal_constraints(self):
        for k in range(1 - self.n, self.n):
            diag1 = [self.vars[i][i-k] for i in range(self.n) if 0 <= i-k < self.n]
            diag2 = [self.vars[i][self.n-1-(i+k)] for i in range(self.n) if 0 <= self.n-1-(i+k) < self.n]
            if len(diag1) > 1:
                self.add_at_most_one(diag1)
            if len(diag2) > 1:
                self.add_at_most_one(diag2)

    def add_at_most_one(self, lits):
        for i in range(len(lits)):
            for j in range(i+1, len(lits)):
                clause = [-lits[i], -lits[j]]
                self.clauses.append(clause)
    
    def solve(self):
        solutions = []
        self.solver.append_formula(self.clauses)
        while self.solver.solve():
            model = self.solver.get_model()
            solution = [[False for j in range(self.n)] for i in range(self.n)]
            for i in range(self.n):
                for j in range(self.n):
                    if model[self.vars[i][j]-1] > 0:
                        solution[i][j] = True
            solutions.append(solution)
            # add a clause to prevent finding the same solution again
            clause = [-lit for lit in model if lit > 0]
            self.solver.add_clause(clause)
        if solutions:
            if len(solutions) == 1:
                print("There is {} solution to the {} x {} problem".format(len(solutions), self.n, self.n))
            else:
                print("There are {} solutions to the {} x {} problem".format(len(solutions), self.n, self.n))
            solution = random.choice(solutions)
            print("Random solution:")
            for i in range(self.n):
                for j in range(self.n):
                    if solution[i][j]:
                        print("Q", end=" ")
                    else:
                        print(".", end=" ")
                print()
        else:
            print("UNSOLVABLE")
            
class EightQueenSolver(NQueenSolver):
    def __init__(self):
        super().__init__(8)

# %% [markdown]
# # Evaluation

# %%
solver = NQueenSolver(5)
solver.solve()
# Out:
# There are 10 solutions to the 5 x 5 problem
# Random solution:
# . . Q . .
# . . . . Q
# . Q . . .
# . . . Q .
# Q . . . .

# %%
solver = EightQueenSolver()
solver.solve()
# Out:
# There are 92 solutions to the 8 x 8 problem
# Random solution:
# . . . . . . Q .
# . Q . . . . . .
# . . . . . Q . .
# . . Q . . . . .
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . . . . Q . . .
